# %% [markdown]
# # Station Usage Simulation Evaluation
#
# Use daily traffic data in 2022 to simulate daily usage.

# %% [markdown]
# ## Target
#
# 1. Analyze the rate in which the stations are built.
#
# 2. How many cars are gaing up? At which area?
#
# 3. Where should we focus on building new charging station?

# %% [markdown]
# ## Assumption
#
# - There are about 400 cars using the charging station per day in general within Bristol.
# - The average flux of cars in 2022 is 804.6 cars per count point per hour.

# %% [markdown]
# # Preperation

# %%
# %pwd
# %cd '../'
# The directory should be '/electrical_vehicle_project_igp'
# Out:
# /Users/trietdoky/Documents/03 Master/MAIN COURSE/00 IGP/00 Project/source_code/electrical_vehicle_project_igp

# %%
import pandas as pd
import numpy as np
import h3
import simpy
from datetime import datetime, timedelta
# import folium     # for jupyter notebooks only
import library.mong_connection as mongo
import library.config as cfg
import data_processing as dpr
import car_simulation as sim
import library.g7_utility as ult
import os
import asyncio

simulation_level = 7
period_start = '2022-01-01 00:00:00'
period_end = '2023-01-01 00:00:00'

# %% [markdown]
# ## Get Daily Traffic Data

# %%
raw_traffic_data = pd.read_csv(os.getcwd()+'/simulation/sys_files/bristol_traffic_density.csv')
# traffic_allocation = dpr.extract_traffic_data()
station_data_simulation = dpr.extract_station_data(simulation_level)
ports_data = dpr.extract_charging_port_data()
raw_station_data, raw_hex_data = dpr.process_traffic_data(simulation_res=simulation_level)
business_ref_table = dpr.generate_business_data(raw_hex_data, raw_station_data)
# Out:
# searching for neighbor of 85195877fffffff
# found neighbors of 85195877fffffff with 0
# searching for neighbor of 8519583bfffffff
# found neighbors of 8519583bfffffff with 0
# searching for neighbor of 8519582bfffffff
# found neighbors of 8519582bfffffff with 0
# searching for neighbor of 85195863fffffff
# found neighbors of 85195863fffffff with 1
# searching for neighbor of 85195873fffffff
# found neighbors of 85195873fffffff with 1
# searching for neighbor of 85195867fffffff
# found neighbors of 85195867fffffff with 0
# searching for neighbor of 8619580cfffffff
# found neighbors of 8619580cfffffff with 0
# searching for neighbor of 861958397ffffff
# found neighbors of 861958397ffffff with 0
# searching for neighbor of 86195862fffffff
# found neighbors of 86195862fffffff with 1
# searching for neighbor of 861958677ffffff
# found neighbors of 861958677ffffff with 1
# searching for neighbor of 861958647ffffff
# found neighbors of 861958647ffffff with 1
# searching for neighbor of 861958657ffffff
# found neighbors of 861958657ffffff with 2
# searching for neighbor of 8619582a7ffffff
# found neighbors of 8619582a7ffffff with 1
# searching for neighbor of 86195875fffffff
# found neighbors of 86195875fffffff with 1
# searching for neighbor of 8619586e7ffffff
# found neighbors of 8619586e7ffffff with 3
# searching for neighbor of 86195866fffffff
# found neighbors of 86195866fffffff with 1
# searching for neighbor of 861958607ffffff
# found neighbors of 861958607ffffff with 2
# searching for neighbor of 861958667ffffff
# found neighbors of 861958667ffffff with 0
# searching for neighbor of 86195829fffffff
# found neighbors of 86195829fffffff with 2
# searching for neighbor of 861958707ffffff
# found neighbors of 861958707ffffff with 2
# searching for neighbor of 861958627ffffff
# found neighbors of 861958627ffffff with 1
# searching for neighbor of 86195839fffffff
# found neighbors of 86195839fffffff with 0
# searching for neighbor of 861958757ffffff
# found neighbors of 861958757ffffff with 0
# searching for neighbor of 86195860fffffff
# found neighbors of 86195860fffffff with 2
# searching for neighbor of 8619586efffffff
# found neighbors of 8619586efffffff with 3
# searching for neighbor of 8619580dfffffff
# found neighbors of 8619580dfffffff with 1
# searching for neighbor of 8619583a7ffffff
# found neighbors of 8619583a7ffffff with 1
# searching for neighbor of 861958637ffffff
# found neighbors of 861958637ffffff with 2
# searching for neighbor of 86195805fffffff
# found neighbors of 86195805fffffff with 0
# searching for neighbor of 8619582b7ffffff
# found neighbors of 8619582b7ffffff with 0
# searching for neighbor of 86195872fffffff
# found neighbors of 86195872fffffff with 1
# searching for neighbor of 86195871fffffff
# found neighbors of 86195871fffffff with 2
# searching for neighbor of 861958387ffffff
# found neighbors of 861958387ffffff with 0
# searching for neighbor of 861958297ffffff
# found neighbors of 861958297ffffff with 1
# searching for neighbor of 86195874fffffff
# found neighbors of 86195874fffffff with 0
# searching for neighbor of 861958747ffffff
# found neighbors of 861958747ffffff with 1
# searching for neighbor of 86195870fffffff
# found neighbors of 86195870fffffff with 1
# searching for neighbor of 861958287ffffff
# found neighbors of 861958287ffffff with 1
# searching for neighbor of 8619582afffffff
# found neighbors of 8619582afffffff with 0
# searching for neighbor of 861958777ffffff
# found neighbors of 861958777ffffff with 0
# searching for neighbor of 8619583b7ffffff
# found neighbors of 8619583b7ffffff with 0
# searching for neighbor of 86195838fffffff
# found neighbors of 86195838fffffff with 1
# searching for neighbor of 86195876fffffff
# found neighbors of 86195876fffffff with 0
# searching for neighbor of 861958767ffffff
# found neighbors of 861958767ffffff with 0
# searching for neighbor of 87195872dffffff
# found neighbors of 87195872dffffff with 3
# searching for neighbor of 871958709ffffff
# found neighbors of 871958709ffffff with 1
# searching for neighbor of 87195862dffffff
# found neighbors of 87195862dffffff with 3
# searching for neighbor of 8719582adffffff
# found neighbors of 8719582adffffff with 2
# searching for neighbor of 871958281ffffff
# found neighbors of 871958281ffffff with 1
# searching for neighbor of 871958771ffffff
# found neighbors of 871958771ffffff with 1
# searching for neighbor of 87195871effffff
# found neighbors of 87195871effffff with 6
# searching for neighbor of 871958742ffffff
# found neighbors of 871958742ffffff with 0
# searching for neighbor of 8719583b6ffffff
# found neighbors of 8719583b6ffffff with 1
# searching for neighbor of 871958643ffffff
# found neighbors of 871958643ffffff with 4
# searching for neighbor of 8719580e9ffffff
# found neighbors of 8719580e9ffffff with 1
# searching for neighbor of 871958392ffffff
# found neighbors of 871958392ffffff with 0
# searching for neighbor of 8719582a1ffffff
# found neighbors of 8719582a1ffffff with 2
# searching for neighbor of 871958743ffffff
# found neighbors of 871958743ffffff with 1
# searching for neighbor of 871958640ffffff
# found neighbors of 871958640ffffff with 3
# searching for neighbor of 87195862effffff
# found neighbors of 87195862effffff with 4
# searching for neighbor of 8719586e1ffffff
# found neighbors of 8719586e1ffffff with 7
# searching for neighbor of 871958746ffffff
# found neighbors of 871958746ffffff with 1
# searching for neighbor of 871958642ffffff
# found neighbors of 871958642ffffff with 4
# searching for neighbor of 87195876cffffff
# found neighbors of 87195876cffffff with 0
# searching for neighbor of 871958673ffffff
# found neighbors of 871958673ffffff with 3
# searching for neighbor of 8719580deffffff
# found neighbors of 8719580deffffff with 3
# searching for neighbor of 871958763ffffff
# found neighbors of 871958763ffffff with 1
# searching for neighbor of 871958672ffffff
# found neighbors of 871958672ffffff with 3
# searching for neighbor of 8719582acffffff
# found neighbors of 8719582acffffff with 2
# searching for neighbor of 871958634ffffff
# found neighbors of 871958634ffffff with 6
# searching for neighbor of 8719580c9ffffff
# found neighbors of 8719580c9ffffff with 0
# searching for neighbor of 87195829affffff
# found neighbors of 87195829affffff with 5
# searching for neighbor of 87195866dffffff
# found neighbors of 87195866dffffff with 4
# searching for neighbor of 87195862cffffff
# found neighbors of 87195862cffffff with 3
# searching for neighbor of 871958754ffffff
# found neighbors of 871958754ffffff with 0
# searching for neighbor of 871958650ffffff
# found neighbors of 871958650ffffff with 5
# searching for neighbor of 871958601ffffff
# found neighbors of 871958601ffffff with 6
# searching for neighbor of 871958653ffffff
# found neighbors of 871958653ffffff with 6
# searching for neighbor of 871958700ffffff
# found neighbors of 871958700ffffff with 4
# searching for neighbor of 87195860cffffff
# found neighbors of 87195860cffffff with 5
# searching for neighbor of 87195839cffffff
# found neighbors of 87195839cffffff with 1
# searching for neighbor of 8719580ebffffff
# found neighbors of 8719580ebffffff with 0
# searching for neighbor of 871958606ffffff
# found neighbors of 871958606ffffff with 6
# searching for neighbor of 8719586e0ffffff
# found neighbors of 8719586e0ffffff with 7
# searching for neighbor of 871958728ffffff
# found neighbors of 871958728ffffff with 3
# searching for neighbor of 871958664ffffff
# found neighbors of 871958664ffffff with 1
# searching for neighbor of 87195805bffffff
# found neighbors of 87195805bffffff with 1
# searching for neighbor of 871958380ffffff
# found neighbors of 871958380ffffff with 1
# searching for neighbor of 871958605ffffff
# found neighbors of 871958605ffffff with 5
# searching for neighbor of 87195874cffffff
# found neighbors of 87195874cffffff with 2
# searching for neighbor of 871958762ffffff
# found neighbors of 871958762ffffff with 1
# searching for neighbor of 8719580caffffff
# found neighbors of 8719580caffffff with 0
# searching for neighbor of 87195872bffffff
# found neighbors of 87195872bffffff with 2
# searching for neighbor of 87195838effffff
# found neighbors of 87195838effffff with 1
# searching for neighbor of 87195862bffffff
# found neighbors of 87195862bffffff with 4
# searching for neighbor of 8719583a3ffffff
# found neighbors of 8719583a3ffffff with 2
# searching for neighbor of 871958750ffffff
# found neighbors of 871958750ffffff with 1
# searching for neighbor of 871958756ffffff
# found neighbors of 871958756ffffff with 1
# searching for neighbor of 87195876dffffff
# found neighbors of 87195876dffffff with 0
# searching for neighbor of 87195828cffffff
# found neighbors of 87195828cffffff with 1
# searching for neighbor of 87195865effffff
# found neighbors of 87195865effffff with 6
# searching for neighbor of 871958603ffffff
# found neighbors of 871958603ffffff with 7
# searching for neighbor of 8719586eeffffff
# found neighbors of 8719586eeffffff with 8
# searching for neighbor of 87195839dffffff
# found neighbors of 87195839dffffff with 0
# searching for neighbor of 871958655ffffff
# found neighbors of 871958655ffffff with 4
# searching for neighbor of 871958391ffffff
# found neighbors of 871958391ffffff with 1
# searching for neighbor of 87195839affffff
# found neighbors of 87195839affffff with 1
# searching for neighbor of 871958652ffffff
# found neighbors of 871958652ffffff with 6
# searching for neighbor of 87195876effffff
# found neighbors of 87195876effffff with 0
# searching for neighbor of 87195874effffff
# found neighbors of 87195874effffff with 1
# searching for neighbor of 871958656ffffff
# found neighbors of 871958656ffffff with 5
# searching for neighbor of 87195861cffffff
# found neighbors of 87195861cffffff with 8
# searching for neighbor of 8719582aeffffff
# found neighbors of 8719582aeffffff with 1
# searching for neighbor of 871958398ffffff
# found neighbors of 871958398ffffff with 1
# searching for neighbor of 871958751ffffff
# found neighbors of 871958751ffffff with 1
# searching for neighbor of 871958668ffffff
# found neighbors of 871958668ffffff with 4
# searching for neighbor of 871958772ffffff
# found neighbors of 871958772ffffff with 0
# searching for neighbor of 8719583a2ffffff
# found neighbors of 8719583a2ffffff with 1
# searching for neighbor of 871958393ffffff
# found neighbors of 871958393ffffff with 0
# searching for neighbor of 8719586eaffffff
# found neighbors of 8719586eaffffff with 9
# searching for neighbor of 8719582a0ffffff
# found neighbors of 8719582a0ffffff with 3
# searching for neighbor of 8719580c3ffffff
# found neighbors of 8719580c3ffffff with 1
# searching for neighbor of 871958620ffffff
# found neighbors of 871958620ffffff with 3
# searching for neighbor of 8719583aaffffff
# found neighbors of 8719583aaffffff with 3
# searching for neighbor of 871958385ffffff
# found neighbors of 871958385ffffff with 2
# searching for neighbor of 87195839effffff
# found neighbors of 87195839effffff with 0
# searching for neighbor of 871958623ffffff
# found neighbors of 871958623ffffff with 4
# searching for neighbor of 871958708ffffff
# found neighbors of 871958708ffffff with 2
# searching for neighbor of 871958600ffffff
# found neighbors of 871958600ffffff with 6
# searching for neighbor of 871958729ffffff
# found neighbors of 871958729ffffff with 2
# searching for neighbor of 87195839bffffff
# found neighbors of 87195839bffffff with 2
# searching for neighbor of 871958394ffffff
# found neighbors of 871958394ffffff with 0
# searching for neighbor of 87195871bffffff
# found neighbors of 87195871bffffff with 5
# searching for neighbor of 871958609ffffff
# found neighbors of 871958609ffffff with 4
# searching for neighbor of 871958663ffffff
# found neighbors of 871958663ffffff with 2
# searching for neighbor of 8719580d9ffffff
# found neighbors of 8719580d9ffffff with 1
# searching for neighbor of 871958661ffffff
# found neighbors of 871958661ffffff with 2
# searching for neighbor of 871958399ffffff
# found neighbors of 871958399ffffff with 1
# searching for neighbor of 8719586e3ffffff
# found neighbors of 8719586e3ffffff with 8
# searching for neighbor of 871958666ffffff
# found neighbors of 871958666ffffff with 0
# searching for neighbor of 871958752ffffff
# found neighbors of 871958752ffffff with 2
# searching for neighbor of 871958701ffffff
# found neighbors of 871958701ffffff with 3
# searching for neighbor of 871958669ffffff
# found neighbors of 871958669ffffff with 5
# searching for neighbor of 871958633ffffff
# found neighbors of 871958633ffffff with 6
# searching for neighbor of 871958761ffffff
# found neighbors of 871958761ffffff with 0
# searching for neighbor of 8719582aaffffff
# found neighbors of 8719582aaffffff with 0
# searching for neighbor of 8719580daffffff
# found neighbors of 8719580daffffff with 2
# searching for neighbor of 87195871cffffff
# found neighbors of 87195871cffffff with 5
# searching for neighbor of 871958766ffffff
# found neighbors of 871958766ffffff with 0
# searching for neighbor of 87195870effffff
# found neighbors of 87195870effffff with 3
# searching for neighbor of 871958760ffffff
# found neighbors of 871958760ffffff with 1
# searching for neighbor of 8719580dbffffff
# found neighbors of 8719580dbffffff with 1
# searching for neighbor of 871958284ffffff
# found neighbors of 871958284ffffff with 2
# searching for neighbor of 8719586ecffffff
# found neighbors of 8719586ecffffff with 7
# searching for neighbor of 871958741ffffff
# found neighbors of 871958741ffffff with 2
# searching for neighbor of 871958296ffffff
# found neighbors of 871958296ffffff with 2
# searching for neighbor of 871958769ffffff
# found neighbors of 871958769ffffff with 0
# searching for neighbor of 871958384ffffff
# found neighbors of 871958384ffffff with 1
# searching for neighbor of 87195870dffffff
# found neighbors of 87195870dffffff with 1
# searching for neighbor of 87195862affffff
# found neighbors of 87195862affffff with 5
# searching for neighbor of 871958713ffffff
# found neighbors of 871958713ffffff with 7
# searching for neighbor of 87195865cffffff
# found neighbors of 87195865cffffff with 5
# searching for neighbor of 8719582a4ffffff
# found neighbors of 8719582a4ffffff with 2
# searching for neighbor of 871958764ffffff
# found neighbors of 871958764ffffff with 1
# searching for neighbor of 8719580c8ffffff
# found neighbors of 8719580c8ffffff with 0
# searching for neighbor of 87195866cffffff
# found neighbors of 87195866cffffff with 3
# searching for neighbor of 8719580cdffffff
# found neighbors of 8719580cdffffff with 0
# searching for neighbor of 871958718ffffff
# found neighbors of 871958718ffffff with 5
# searching for neighbor of 87195870bffffff
# found neighbors of 87195870bffffff with 2
# searching for neighbor of 8719582b3ffffff
# found neighbors of 8719582b3ffffff with 1
# searching for neighbor of 871958283ffffff
# found neighbors of 871958283ffffff with 2
# searching for neighbor of 8719586e4ffffff
# found neighbors of 8719586e4ffffff with 6
# searching for neighbor of 871958745ffffff
# found neighbors of 871958745ffffff with 1
# searching for neighbor of 87195828effffff
# found neighbors of 87195828effffff with 2
# searching for neighbor of 871958282ffffff
# found neighbors of 871958282ffffff with 3
# searching for neighbor of 871958630ffffff
# found neighbors of 871958630ffffff with 6
# searching for neighbor of 8719582b0ffffff
# found neighbors of 8719582b0ffffff with 1
# searching for neighbor of 871958635ffffff
# found neighbors of 871958635ffffff with 5
# searching for neighbor of 87195871dffffff
# found neighbors of 87195871dffffff with 4
# searching for neighbor of 8719582a5ffffff
# found neighbors of 8719582a5ffffff with 3
# searching for neighbor of 871958744ffffff
# found neighbors of 871958744ffffff with 2
# searching for neighbor of 871958740ffffff
# found neighbors of 871958740ffffff with 1
# searching for neighbor of 871958621ffffff
# found neighbors of 871958621ffffff with 3
# searching for neighbor of 871958631ffffff
# found neighbors of 871958631ffffff with 5
# searching for neighbor of 8719586e6ffffff
# found neighbors of 8719586e6ffffff with 7
# searching for neighbor of 871958765ffffff
# found neighbors of 871958765ffffff with 0
# searching for neighbor of 871958645ffffff
# found neighbors of 871958645ffffff with 3
# searching for neighbor of 871958703ffffff
# found neighbors of 871958703ffffff with 4
# searching for neighbor of 87195866affffff
# found neighbors of 87195866affffff with 4
# searching for neighbor of 871958662ffffff
# found neighbors of 871958662ffffff with 1
# searching for neighbor of 871958749ffffff
# found neighbors of 871958749ffffff with 1
# searching for neighbor of 871958748ffffff
# found neighbors of 871958748ffffff with 1
# searching for neighbor of 871958619ffffff
# found neighbors of 871958619ffffff with 7
# searching for neighbor of 87195875cffffff
# found neighbors of 87195875cffffff with 1
# searching for neighbor of 8719586e8ffffff
# found neighbors of 8719586e8ffffff with 8
# searching for neighbor of 871958608ffffff
# found neighbors of 871958608ffffff with 5
# searching for neighbor of 8719583b5ffffff
# found neighbors of 8719583b5ffffff with 0
# searching for neighbor of 871958604ffffff
# found neighbors of 871958604ffffff with 5
# searching for neighbor of 871958058ffffff
# found neighbors of 871958058ffffff with 1
# searching for neighbor of 871958644ffffff
# found neighbors of 871958644ffffff with 2
# searching for neighbor of 87195875affffff
# found neighbors of 87195875affffff with 2
# searching for neighbor of 871958629ffffff
# found neighbors of 871958629ffffff with 3
# searching for neighbor of 871958388ffffff
# found neighbors of 871958388ffffff with 2
# searching for neighbor of 8719583a0ffffff
# found neighbors of 8719583a0ffffff with 2
# searching for neighbor of 87195875dffffff
# found neighbors of 87195875dffffff with 1
# searching for neighbor of 871958671ffffff
# found neighbors of 871958671ffffff with 2
# searching for neighbor of 87195805dffffff
# found neighbors of 87195805dffffff with 0
# searching for neighbor of 871958624ffffff
# found neighbors of 871958624ffffff with 3
# searching for neighbor of 871958290ffffff
# found neighbors of 871958290ffffff with 2
# searching for neighbor of 87195829cffffff
# found neighbors of 87195829cffffff with 3
# searching for neighbor of 8719586edffffff
# found neighbors of 8719586edffffff with 7
# searching for neighbor of 871958294ffffff
# found neighbors of 871958294ffffff with 1
# searching for neighbor of 871958702ffffff
# found neighbors of 871958702ffffff with 5
# searching for neighbor of 8719582a6ffffff
# found neighbors of 8719582a6ffffff with 2
# searching for neighbor of 8719580d8ffffff
# found neighbors of 8719580d8ffffff with 2
# searching for neighbor of 871958292ffffff
# found neighbors of 871958292ffffff with 3
# searching for neighbor of 87195838bffffff
# found neighbors of 87195838bffffff with 2
# searching for neighbor of 871958625ffffff
# found neighbors of 871958625ffffff with 2
# searching for neighbor of 871958675ffffff
# found neighbors of 871958675ffffff with 1
# searching for neighbor of 87195829effffff
# found neighbors of 87195829effffff with 4
# searching for neighbor of 8719583b1ffffff
# found neighbors of 8719583b1ffffff with 0
# searching for neighbor of 871958646ffffff
# found neighbors of 871958646ffffff with 3
# searching for neighbor of 871958773ffffff
# found neighbors of 871958773ffffff with 1
# searching for neighbor of 87195870cffffff
# found neighbors of 87195870cffffff with 2
# searching for neighbor of 871958665ffffff
# found neighbors of 871958665ffffff with 2
# searching for neighbor of 871958395ffffff
# found neighbors of 871958395ffffff with 0
# searching for neighbor of 8719582b4ffffff
# found neighbors of 8719582b4ffffff with 1
# searching for neighbor of 8719582a8ffffff
# found neighbors of 8719582a8ffffff with 1
# searching for neighbor of 87195860effffff
# found neighbors of 87195860effffff with 6
# searching for neighbor of 871958293ffffff
# found neighbors of 871958293ffffff with 3
# searching for neighbor of 87195870affffff
# found neighbors of 87195870affffff with 3
# searching for neighbor of 871958396ffffff
# found neighbors of 871958396ffffff with 0
# searching for neighbor of 87195860bffffff
# found neighbors of 87195860bffffff with 5
# searching for neighbor of 8719580ddffffff
# found neighbors of 8719580ddffffff with 1
# searching for neighbor of 871958753ffffff
# found neighbors of 871958753ffffff with 2
# searching for neighbor of 8719583a6ffffff
# found neighbors of 8719583a6ffffff with 1
# searching for neighbor of 8719582b2ffffff
# found neighbors of 8719582b2ffffff with 0
# searching for neighbor of 871958670ffffff
# found neighbors of 871958670ffffff with 2
# searching for neighbor of 87195829dffffff
# found neighbors of 87195829dffffff with 3
# searching for neighbor of 871958674ffffff
# found neighbors of 871958674ffffff with 2
# searching for neighbor of 871958389ffffff
# found neighbors of 871958389ffffff with 3
# searching for neighbor of 871958676ffffff
# found neighbors of 871958676ffffff with 3
# searching for neighbor of 87195874bffffff
# found neighbors of 87195874bffffff with 1
# searching for neighbor of 8719587a9ffffff
# found neighbors of 8719587a9ffffff with 7
# searching for neighbor of 87195805affffff
# found neighbors of 87195805affffff with 2
# searching for neighbor of 8719582a3ffffff
# found neighbors of 8719582a3ffffff with 2
# searching for neighbor of 871958774ffffff
# found neighbors of 871958774ffffff with 1
# searching for neighbor of 871958295ffffff
# found neighbors of 871958295ffffff with 2
# searching for neighbor of 871958768ffffff
# found neighbors of 871958768ffffff with 1
# searching for neighbor of 871958381ffffff
# found neighbors of 871958381ffffff with 2
# searching for neighbor of 871958660ffffff
# found neighbors of 871958660ffffff with 1
# searching for neighbor of 871958641ffffff
# found neighbors of 871958641ffffff with 4
# searching for neighbor of 871958390ffffff
# found neighbors of 871958390ffffff with 0
# searching for neighbor of 8719583b4ffffff
# found neighbors of 8719583b4ffffff with 1
# searching for neighbor of 8719582b5ffffff
# found neighbors of 8719582b5ffffff with 2
# searching for neighbor of 8719580dcffffff
# found neighbors of 8719580dcffffff with 2
# searching for neighbor of 871958213ffffff
# found neighbors of 871958213ffffff with 3
# searching for neighbor of 8719582abffffff
# found neighbors of 8719582abffffff with 1
# searching for neighbor of 871958711ffffff
# found neighbors of 871958711ffffff with 6
# searching for neighbor of 871958383ffffff
# found neighbors of 871958383ffffff with 1
# searching for neighbor of 8719587adffffff
# found neighbors of 8719587adffffff with 7
# searching for neighbor of 871958298ffffff
# found neighbors of 871958298ffffff with 4
# searching for neighbor of 871958280ffffff
# found neighbors of 871958280ffffff with 2
# searching for neighbor of 871958755ffffff
# found neighbors of 871958755ffffff with 1
# searching for neighbor of 871958776ffffff
# found neighbors of 871958776ffffff with 1
# searching for neighbor of 8719582b1ffffff
# found neighbors of 8719582b1ffffff with 2
# searching for neighbor of 8719580ccffffff
# found neighbors of 8719580ccffffff with 0
# searching for neighbor of 8719586c5ffffff
# found neighbors of 8719586c5ffffff with 9
# searching for neighbor of 871958622ffffff
# found neighbors of 871958622ffffff with 4
# searching for neighbor of 87195874affffff
# found neighbors of 87195874affffff with 0
# searching for neighbor of 87195860affffff
# found neighbors of 87195860affffff with 6
# searching for neighbor of 8719580eaffffff
# found neighbors of 8719580eaffffff with 1
# searching for neighbor of 871958758ffffff
# found neighbors of 871958758ffffff with 2
# searching for neighbor of 871958216ffffff
# found neighbors of 871958216ffffff with 3
# searching for neighbor of 8719586e5ffffff
# found neighbors of 8719586e5ffffff with 6
# searching for neighbor of 87195866effffff
# found neighbors of 87195866effffff with 3
# searching for neighbor of 871958770ffffff
# found neighbors of 871958770ffffff with 1
# searching for neighbor of 871958285ffffff
# found neighbors of 871958285ffffff with 1
# searching for neighbor of 871958719ffffff
# found neighbors of 871958719ffffff with 4
# searching for neighbor of 8719582a9ffffff
# found neighbors of 8719582a9ffffff with 2
# searching for neighbor of 87195838affffff
# found neighbors of 87195838affffff with 1
# searching for neighbor of 87195860dffffff
# found neighbors of 87195860dffffff with 4
# searching for neighbor of 87195871affffff
# found neighbors of 87195871affffff with 6
# searching for neighbor of 8719580ceffffff
# found neighbors of 8719580ceffffff with 0
# searching for neighbor of 871958386ffffff
# found neighbors of 871958386ffffff with 0
# searching for neighbor of 8719582a2ffffff
# found neighbors of 8719582a2ffffff with 3
# searching for neighbor of 871958628ffffff
# found neighbors of 871958628ffffff with 4
# searching for neighbor of 871958651ffffff
# found neighbors of 871958651ffffff with 5
# searching for neighbor of 871958759ffffff
# found neighbors of 871958759ffffff with 1
# searching for neighbor of 87195876bffffff
# found neighbors of 87195876bffffff with 1
# searching for neighbor of 87195838cffffff
# found neighbors of 87195838cffffff with 2
# searching for neighbor of 87195874dffffff
# found neighbors of 87195874dffffff with 1
# searching for neighbor of 871958212ffffff
# found neighbors of 871958212ffffff with 3
# searching for neighbor of 8719582b6ffffff
# found neighbors of 8719582b6ffffff with 1
# searching for neighbor of 871958626ffffff
# found neighbors of 871958626ffffff with 4
# searching for neighbor of 871958775ffffff
# found neighbors of 871958775ffffff with 0
# searching for neighbor of 871958286ffffff
# found neighbors of 871958286ffffff with 2
# searching for neighbor of 8719580cbffffff
# found neighbors of 8719580cbffffff with 0
# searching for neighbor of 87195876affffff
# found neighbors of 87195876affffff with 1
# searching for neighbor of 8719583b0ffffff
# found neighbors of 8719583b0ffffff with 0
# searching for neighbor of 871958291ffffff
# found neighbors of 871958291ffffff with 3
# searching for neighbor of 871958602ffffff
# found neighbors of 871958602ffffff with 7
# searching for neighbor of 8719583b2ffffff
# found neighbors of 8719583b2ffffff with 0
# searching for neighbor of 8719583b3ffffff
# found neighbors of 8719583b3ffffff with 0
# searching for neighbor of 87195875effffff
# found neighbors of 87195875effffff with 2
# searching for neighbor of 871958059ffffff
# found neighbors of 871958059ffffff with 1
# searching for neighbor of 8719580c1ffffff
# found neighbors of 8719580c1ffffff with 1
# searching for neighbor of 87195875bffffff
# found neighbors of 87195875bffffff with 1
# searching for neighbor of 87195861dffffff
# found neighbors of 87195861dffffff with 7
# searching for neighbor of 871958382ffffff
# found neighbors of 871958382ffffff with 0
# searching for neighbor of 871958654ffffff
# found neighbors of 871958654ffffff with 4
# searching for neighbor of 87195872affffff
# found neighbors of 87195872affffff with 3
# searching for neighbor of 88195862e7fffff
# found neighbors of 88195862e7fffff with 10
# searching for neighbor of 8819583837fffff
# found neighbors of 8819583837fffff with 1
# searching for neighbor of 88195870e7fffff
# found neighbors of 88195870e7fffff with 8
# searching for neighbor of 88195805ddfffff
# found neighbors of 88195805ddfffff with 2
# searching for neighbor of 881958754dfffff
# found neighbors of 881958754dfffff with 1
# searching for neighbor of 881958286dfffff
# found neighbors of 881958286dfffff with 4
# searching for neighbor of 8819583a21fffff
# found neighbors of 8819583a21fffff with 2
# searching for neighbor of 8819582b63fffff
# found neighbors of 8819582b63fffff with 2
# searching for neighbor of 8819586055fffff
# found neighbors of 8819586055fffff with 13
# searching for neighbor of 881958750bfffff
# found neighbors of 881958750bfffff with 3
# searching for neighbor of 88195829abfffff
# found neighbors of 88195829abfffff with 13
# searching for neighbor of 8819580d8bfffff
# found neighbors of 8819580d8bfffff with 4
# searching for neighbor of 88195829dbfffff
# found neighbors of 88195829dbfffff with 7
# searching for neighbor of 8819580593fffff
# found neighbors of 8819580593fffff with 3
# searching for neighbor of 88195860a5fffff
# found neighbors of 88195860a5fffff with 17
# searching for neighbor of 88195829d5fffff
# found neighbors of 88195829d5fffff with 9
# searching for neighbor of 88195839e3fffff
# found neighbors of 88195839e3fffff with 1
# searching for neighbor of 8819583995fffff
# found neighbors of 8819583995fffff with 3
# searching for neighbor of 88195876e1fffff
# found neighbors of 88195876e1fffff with 0
# searching for neighbor of 8819586401fffff
# found neighbors of 8819586401fffff with 8
# searching for neighbor of 88195866c9fffff
# found neighbors of 88195866c9fffff with 8
# searching for neighbor of 8819586625fffff
# found neighbors of 8819586625fffff with 3
# searching for neighbor of 8819582ab7fffff
# found neighbors of 8819582ab7fffff with 2
# searching for neighbor of 8819586505fffff
# found neighbors of 8819586505fffff with 14
# searching for neighbor of 8819587719fffff
# found neighbors of 8819587719fffff with 2
# searching for neighbor of 88195874b3fffff
# found neighbors of 88195874b3fffff with 5
# searching for neighbor of 8819582b0dfffff
# found neighbors of 8819582b0dfffff with 2
# searching for neighbor of 881958741dfffff
# found neighbors of 881958741dfffff with 5
# searching for neighbor of 881958390dfffff
# found neighbors of 881958390dfffff with 1
# searching for neighbor of 8819580585fffff
# found neighbors of 8819580585fffff with 4
# searching for neighbor of 88195876e7fffff
# found neighbors of 88195876e7fffff with 1
# searching for neighbor of 8819587139fffff
# found neighbors of 8819587139fffff with 18
# searching for neighbor of 88195838b9fffff
# found neighbors of 88195838b9fffff with 6
# searching for neighbor of 88195876e5fffff
# found neighbors of 88195876e5fffff with 1
# searching for neighbor of 8819586193fffff
# found neighbors of 8819586193fffff with 19
# searching for neighbor of 88195874d7fffff
# found neighbors of 88195874d7fffff with 4
# searching for neighbor of 8819587acbfffff
# found neighbors of 8819587acbfffff with 19
# searching for neighbor of 88195876a9fffff
# found neighbors of 88195876a9fffff with 1
# searching for neighbor of 8819580e93fffff
# found neighbors of 8819580e93fffff with 4
# searching for neighbor of 8819580cebfffff
# found neighbors of 8819580cebfffff with 1
# searching for neighbor of 8819580cd7fffff
# found neighbors of 8819580cd7fffff with 1
# searching for neighbor of 8819580c17fffff
# found neighbors of 8819580c17fffff with 3
# searching for neighbor of 8819582a2dfffff
# found neighbors of 8819582a2dfffff with 6
# searching for neighbor of 8819586537fffff
# found neighbors of 8819586537fffff with 16
# searching for neighbor of 881958382dfffff
# found neighbors of 881958382dfffff with 1
# searching for neighbor of 881958293bfffff
# found neighbors of 881958293bfffff with 9
# searching for neighbor of 8819582a43fffff
# found neighbors of 8819582a43fffff with 6
# searching for neighbor of 8819580587fffff
# found neighbors of 8819580587fffff with 4
# searching for neighbor of 881958642bfffff
# found neighbors of 881958642bfffff with 9
# searching for neighbor of 88195861c9fffff
# found neighbors of 88195861c9fffff with 19
# searching for neighbor of 8819587611fffff
# found neighbors of 8819587611fffff with 1
# searching for neighbor of 8819583933fffff
# found neighbors of 8819583933fffff with 1
# searching for neighbor of 881958674bfffff
# found neighbors of 881958674bfffff with 5
# searching for neighbor of 88195871e1fffff
# found neighbors of 88195871e1fffff with 15
# searching for neighbor of 8819583a33fffff
# found neighbors of 8819583a33fffff with 5
# searching for neighbor of 8819586087fffff
# found neighbors of 8819586087fffff with 14
# searching for neighbor of 8819586647fffff
# found neighbors of 8819586647fffff with 2
# searching for neighbor of 8819587469fffff
# found neighbors of 8819587469fffff with 4
# searching for neighbor of 881958745dfffff
# found neighbors of 881958745dfffff with 3
# searching for neighbor of 881958602bfffff
# found neighbors of 881958602bfffff with 17
# searching for neighbor of 88195839ddfffff
# found neighbors of 88195839ddfffff with 1
# searching for neighbor of 881958713dfffff
# found neighbors of 881958713dfffff with 19
# searching for neighbor of 881958600dfffff
# found neighbors of 881958600dfffff with 15
# searching for neighbor of 881958729bfffff
# found neighbors of 881958729bfffff with 6
# searching for neighbor of 8819582165fffff
# found neighbors of 8819582165fffff with 8
# searching for neighbor of 8819582acbfffff
# found neighbors of 8819582acbfffff with 6
# searching for neighbor of 8819582a57fffff
# found neighbors of 8819582a57fffff with 8
# searching for neighbor of 8819586ea1fffff
# found neighbors of 8819586ea1fffff with 23
# searching for neighbor of 88195829a9fffff
# found neighbors of 88195829a9fffff with 13
# searching for neighbor of 881958756dfffff
# found neighbors of 881958756dfffff with 2
# searching for neighbor of 8819580d89fffff
# found neighbors of 8819580d89fffff with 5
# searching for neighbor of 88195828e1fffff
# found neighbors of 88195828e1fffff with 5
# searching for neighbor of 88195874bdfffff
# found neighbors of 88195874bdfffff with 3
# searching for neighbor of 8819586013fffff
# found neighbors of 8819586013fffff with 14
# searching for neighbor of 8819587669fffff
# found neighbors of 8819587669fffff with 3
# searching for neighbor of 8819582aadfffff
# found neighbors of 8819582aadfffff with 2
# searching for neighbor of 881958711bfffff
# found neighbors of 881958711bfffff with 15
# searching for neighbor of 88195870c5fffff
# found neighbors of 88195870c5fffff with 7
# searching for neighbor of 8819580595fffff
# found neighbors of 8819580595fffff with 3
# searching for neighbor of 88195839a5fffff
# found neighbors of 88195839a5fffff with 0
# searching for neighbor of 88195872a1fffff
# found neighbors of 88195872a1fffff with 8
# searching for neighbor of 881958776dfffff
# found neighbors of 881958776dfffff with 4
# searching for neighbor of 8819582821fffff
# found neighbors of 8819582821fffff with 7
# searching for neighbor of 8819583955fffff
# found neighbors of 8819583955fffff with 1
# searching for neighbor of 881958620bfffff
# found neighbors of 881958620bfffff with 7
# searching for neighbor of 881958646dfffff
# found neighbors of 881958646dfffff with 7
# searching for neighbor of 8819586003fffff
# found neighbors of 8819586003fffff with 15
# searching for neighbor of 8819587183fffff
# found neighbors of 8819587183fffff with 11
# searching for neighbor of 8819586e63fffff
# found neighbors of 8819586e63fffff with 21
# searching for neighbor of 8819582841fffff
# found neighbors of 8819582841fffff with 7
# searching for neighbor of 8819580dc5fffff
# found neighbors of 8819580dc5fffff with 7
# searching for neighbor of 8819586369fffff
# found neighbors of 8819586369fffff with 15
# searching for neighbor of 881958745bfffff
# found neighbors of 881958745bfffff with 2
# searching for neighbor of 881958662dfffff
# found neighbors of 881958662dfffff with 2
# searching for neighbor of 8819586091fffff
# found neighbors of 8819586091fffff with 12
# searching for neighbor of 88195862e3fffff
# found neighbors of 88195862e3fffff with 9
# searching for neighbor of 8819586095fffff
# found neighbors of 8819586095fffff with 13
# searching for neighbor of 8819580ed7fffff
# found neighbors of 8819580ed7fffff with 4
# searching for neighbor of 8819587193fffff
# found neighbors of 8819587193fffff with 8
# searching for neighbor of 88195862b9fffff
# found neighbors of 88195862b9fffff with 11
# searching for neighbor of 88195866d7fffff
# found neighbors of 88195866d7fffff with 11
# searching for neighbor of 881958650dfffff
# found neighbors of 881958650dfffff with 13
# searching for neighbor of 8819586189fffff
# found neighbors of 8819586189fffff with 19
# searching for neighbor of 8819586e61fffff
# found neighbors of 8819586e61fffff with 21
# searching for neighbor of 88195874abfffff
# found neighbors of 88195874abfffff with 2
# searching for neighbor of 8819586663fffff
# found neighbors of 8819586663fffff with 0
# searching for neighbor of 8819586e31fffff
# found neighbors of 8819586e31fffff with 22
# searching for neighbor of 8819587511fffff
# found neighbors of 8819587511fffff with 2
# searching for neighbor of 88195865e1fffff
# found neighbors of 88195865e1fffff with 14
# searching for neighbor of 8819580de3fffff
# found neighbors of 8819580de3fffff with 7
# searching for neighbor of 8819580eb9fffff
# found neighbors of 8819580eb9fffff with 1
# searching for neighbor of 8819582933fffff
# found neighbors of 8819582933fffff with 10
# searching for neighbor of 8819580e9dfffff
# found neighbors of 8819580e9dfffff with 3
# searching for neighbor of 8819583849fffff
# found neighbors of 8819583849fffff with 2
# searching for neighbor of 8819582b6bfffff
# found neighbors of 8819582b6bfffff with 3
# searching for neighbor of 8819587637fffff
# found neighbors of 8819587637fffff with 3
# searching for neighbor of 8819586237fffff
# found neighbors of 8819586237fffff with 11
# searching for neighbor of 8819580dd5fffff
# found neighbors of 8819580dd5fffff with 4
# searching for neighbor of 8819582a21fffff
# found neighbors of 8819582a21fffff with 6
# searching for neighbor of 88195875cdfffff
# found neighbors of 88195875cdfffff with 2
# searching for neighbor of 8819582a1dfffff
# found neighbors of 8819582a1dfffff with 8
# searching for neighbor of 88195870ddfffff
# found neighbors of 88195870ddfffff with 5
# searching for neighbor of 8819587549fffff
# found neighbors of 8819587549fffff with 2
# searching for neighbor of 881958058dfffff
# found neighbors of 881958058dfffff with 4
# searching for neighbor of 8819582935fffff
# found neighbors of 8819582935fffff with 9
# searching for neighbor of 8819586507fffff
# found neighbors of 8819586507fffff with 14
# searching for neighbor of 881958213dfffff
# found neighbors of 881958213dfffff with 8
# searching for neighbor of 88195876edfffff
# found neighbors of 88195876edfffff with 1
# searching for neighbor of 88195805b3fffff
# found neighbors of 88195805b3fffff with 3
# searching for neighbor of 8819587731fffff
# found neighbors of 8819587731fffff with 2
# searching for neighbor of 8819582b11fffff
# found neighbors of 8819582b11fffff with 4
# searching for neighbor of 8819586551fffff
# found neighbors of 8819586551fffff with 10
# searching for neighbor of 8819582b3bfffff
# found neighbors of 8819582b3bfffff with 3
# searching for neighbor of 8819580591fffff
# found neighbors of 8819580591fffff with 2
# searching for neighbor of 881958752bfffff
# found neighbors of 881958752bfffff with 4
# searching for neighbor of 88195866d3fffff
# found neighbors of 88195866d3fffff with 12
# searching for neighbor of 8819586547fffff
# found neighbors of 8819586547fffff with 12
# searching for neighbor of 88195865c9fffff
# found neighbors of 88195865c9fffff with 11
# searching for neighbor of 8819583939fffff
# found neighbors of 8819583939fffff with 1
# searching for neighbor of 8819582b0bfffff
# found neighbors of 8819582b0bfffff with 3
# searching for neighbor of 8819586755fffff
# found neighbors of 8819586755fffff with 4
# searching for neighbor of 8819586ec1fffff
# found neighbors of 8819586ec1fffff with 18
# searching for neighbor of 8819587189fffff
# found neighbors of 8819587189fffff with 12
# searching for neighbor of 88195861d5fffff
# found neighbors of 88195861d5fffff with 18
# searching for neighbor of 8819583a35fffff
# found neighbors of 8819583a35fffff with 3
# searching for neighbor of 88195876c1fffff
# found neighbors of 88195876c1fffff with 1
# searching for neighbor of 8819582941fffff
# found neighbors of 8819582941fffff with 3
# searching for neighbor of 8819586423fffff
# found neighbors of 8819586423fffff with 10
# searching for neighbor of 8819587755fffff
# found neighbors of 8819587755fffff with 2
# searching for neighbor of 88195838e3fffff
# found neighbors of 88195838e3fffff with 3
# searching for neighbor of 88195871b1fffff
# found neighbors of 88195871b1fffff with 11
# searching for neighbor of 88195839bdfffff
# found neighbors of 88195839bdfffff with 3
# searching for neighbor of 8819582a63fffff
# found neighbors of 8819582a63fffff with 7
# searching for neighbor of 88195860c7fffff
# found neighbors of 88195860c7fffff with 13
# searching for neighbor of 88195860adfffff
# found neighbors of 88195860adfffff with 16
# searching for neighbor of 8819582a03fffff
# found neighbors of 8819582a03fffff with 8
# searching for neighbor of 88195860c5fffff
# found neighbors of 88195860c5fffff with 14
# searching for neighbor of 88195874d1fffff
# found neighbors of 88195874d1fffff with 4
# searching for neighbor of 8819586089fffff
# found neighbors of 8819586089fffff with 12
# searching for neighbor of 8819586267fffff
# found neighbors of 8819586267fffff with 10
# searching for neighbor of 8819586283fffff
# found neighbors of 8819586283fffff with 10
# searching for neighbor of 881958769bfffff
# found neighbors of 881958769bfffff with 1
# searching for neighbor of 8819582947fffff
# found neighbors of 8819582947fffff with 4
# searching for neighbor of 881958708bfffff
# found neighbors of 881958708bfffff with 4
# searching for neighbor of 8819586525fffff
# found neighbors of 8819586525fffff with 17
# searching for neighbor of 8819583901fffff
# found neighbors of 8819583901fffff with 0
# searching for neighbor of 8819582867fffff
# found neighbors of 8819582867fffff with 5
# searching for neighbor of 8819586729fffff
# found neighbors of 8819586729fffff with 8
# searching for neighbor of 8819582931fffff
# found neighbors of 8819582931fffff with 9
# searching for neighbor of 8819582913fffff
# found neighbors of 8819582913fffff with 9
# searching for neighbor of 8819582847fffff
# found neighbors of 8819582847fffff with 7
# searching for neighbor of 8819580ca3fffff
# found neighbors of 8819580ca3fffff with 2
# searching for neighbor of 881958212bfffff
# found neighbors of 881958212bfffff with 8
# searching for neighbor of 881958609dfffff
# found neighbors of 881958609dfffff with 12
# searching for neighbor of 8819583821fffff
# found neighbors of 8819583821fffff with 1
# searching for neighbor of 8819587293fffff
# found neighbors of 8819587293fffff with 5
# searching for neighbor of 8819580dbbfffff
# found neighbors of 8819580dbbfffff with 3
# searching for neighbor of 8819582ab5fffff
# found neighbors of 8819582ab5fffff with 1
# searching for neighbor of 8819582131fffff
# found neighbors of 8819582131fffff with 8
# searching for neighbor of 8819586533fffff
# found neighbors of 8819586533fffff with 15
# searching for neighbor of 8819586e8bfffff
# found neighbors of 8819586e8bfffff with 19
# searching for neighbor of 88195860d9fffff
# found neighbors of 88195860d9fffff with 10
# searching for neighbor of 88195876d1fffff
# found neighbors of 88195876d1fffff with 1
# searching for neighbor of 88195862e5fffff
# found neighbors of 88195862e5fffff with 10
# searching for neighbor of 8819586e1bfffff
# found neighbors of 8819586e1bfffff with 18
# searching for neighbor of 8819587537fffff
# found neighbors of 8819587537fffff with 6
# searching for neighbor of 8819580cc9fffff
# found neighbors of 8819580cc9fffff with 0
# searching for neighbor of 8819587053fffff
# found neighbors of 8819587053fffff with 10
# searching for neighbor of 8819587003fffff
# found neighbors of 8819587003fffff with 11
# searching for neighbor of 8819587683fffff
# found neighbors of 8819587683fffff with 2
# searching for neighbor of 8819583b51fffff
# found neighbors of 8819583b51fffff with 1
# searching for neighbor of 881958740dfffff
# found neighbors of 881958740dfffff with 4
# searching for neighbor of 881958654bfffff
# found neighbors of 881958654bfffff with 10
# searching for neighbor of 8819586667fffff
# found neighbors of 8819586667fffff with 1
# searching for neighbor of 8819586ea9fffff
# found neighbors of 8819586ea9fffff with 22
# searching for neighbor of 881958625dfffff
# found neighbors of 881958625dfffff with 5
# searching for neighbor of 8819587027fffff
# found neighbors of 8819587027fffff with 14
# searching for neighbor of 88195829d7fffff
# found neighbors of 88195829d7fffff with 9
# searching for neighbor of 88195862bbfffff
# found neighbors of 88195862bbfffff with 10
# searching for neighbor of 8819582865fffff
# found neighbors of 8819582865fffff with 4
# searching for neighbor of 8819583893fffff
# found neighbors of 8819583893fffff with 9
# searching for neighbor of 8819582aa5fffff
# found neighbors of 8819582aa5fffff with 2
# searching for neighbor of 8819583b01fffff
# found neighbors of 8819583b01fffff with 1
# searching for neighbor of 8819587629fffff
# found neighbors of 8819587629fffff with 2
# searching for neighbor of 8819583989fffff
# found neighbors of 8819583989fffff with 2
# searching for neighbor of 8819580cdbfffff
# found neighbors of 8819580cdbfffff with 0
# searching for neighbor of 88195839c1fffff
# found neighbors of 88195839c1fffff with 2
# searching for neighbor of 88195862e9fffff
# found neighbors of 88195862e9fffff with 8
# searching for neighbor of 88195838abfffff
# found neighbors of 88195838abfffff with 4
# searching for neighbor of 8819582849fffff
# found neighbors of 8819582849fffff with 7
# searching for neighbor of 8819580c11fffff
# found neighbors of 8819580c11fffff with 3
# searching for neighbor of 88195860bbfffff
# found neighbors of 88195860bbfffff with 14
# searching for neighbor of 881958759dfffff
# found neighbors of 881958759dfffff with 3
# searching for neighbor of 8819586ec9fffff
# found neighbors of 8819586ec9fffff with 17
# searching for neighbor of 881958600bfffff
# found neighbors of 881958600bfffff with 14
# searching for neighbor of 8819586513fffff
# found neighbors of 8819586513fffff with 12
# searching for neighbor of 8819587a99fffff
# found neighbors of 8819587a99fffff with 16
# searching for neighbor of 8819580eb3fffff
# found neighbors of 8819580eb3fffff with 2
# searching for neighbor of 8819587613fffff
# found neighbors of 8819587613fffff with 1
# searching for neighbor of 8819582a83fffff
# found neighbors of 8819582a83fffff with 3
# searching for neighbor of 8819586e49fffff
# found neighbors of 8819586e49fffff with 17
# searching for neighbor of 881958728dfffff
# found neighbors of 881958728dfffff with 9
# searching for neighbor of 8819587595fffff
# found neighbors of 8819587595fffff with 4
# searching for neighbor of 8819583b2bfffff
# found neighbors of 8819583b2bfffff with 1
# searching for neighbor of 8819586e41fffff
# found neighbors of 8819586e41fffff with 18
# searching for neighbor of 8819580cc1fffff
# found neighbors of 8819580cc1fffff with 0
# searching for neighbor of 88195838d7fffff
# found neighbors of 88195838d7fffff with 7
# searching for neighbor of 8819583917fffff
# found neighbors of 8819583917fffff with 1
# searching for neighbor of 8819582853fffff
# found neighbors of 8819582853fffff with 3
# searching for neighbor of 88195805bdfffff
# found neighbors of 88195805bdfffff with 5
# searching for neighbor of 88195871c3fffff
# found neighbors of 88195871c3fffff with 12
# searching for neighbor of 881958216bfffff
# found neighbors of 881958216bfffff with 10
# searching for neighbor of 8819580d8dfffff
# found neighbors of 8819580d8dfffff with 6
# searching for neighbor of 8819582b13fffff
# found neighbors of 8819582b13fffff with 5
# searching for neighbor of 8819586ed9fffff
# found neighbors of 8819586ed9fffff with 16
# searching for neighbor of 8819582905fffff
# found neighbors of 8819582905fffff with 6
# searching for neighbor of 88195861c3fffff
# found neighbors of 88195861c3fffff with 19
# searching for neighbor of 8819587703fffff
# found neighbors of 8819587703fffff with 2
# searching for neighbor of 88195862bdfffff
# found neighbors of 88195862bdfffff with 12
# searching for neighbor of 8819586655fffff
# found neighbors of 8819586655fffff with 3
# searching for neighbor of 881958675bfffff
# found neighbors of 881958675bfffff with 2
# searching for neighbor of 8819586201fffff
# found neighbors of 8819586201fffff with 8
# searching for neighbor of 8819580dbdfffff
# found neighbors of 8819580dbdfffff with 4
# searching for neighbor of 8819583985fffff
# found neighbors of 8819583985fffff with 2
# searching for neighbor of 8819582b21fffff
# found neighbors of 8819582b21fffff with 1
# searching for neighbor of 88195865c1fffff
# found neighbors of 88195865c1fffff with 12
# searching for neighbor of 881958748bfffff
# found neighbors of 881958748bfffff with 4
# searching for neighbor of 8819587529fffff
# found neighbors of 8819587529fffff with 3
# searching for neighbor of 8819583925fffff
# found neighbors of 8819583925fffff with 1
# searching for neighbor of 8819586621fffff
# found neighbors of 8819586621fffff with 2
# searching for neighbor of 88195828c1fffff
# found neighbors of 88195828c1fffff with 2
# searching for neighbor of 8819582951fffff
# found neighbors of 8819582951fffff with 5
# searching for neighbor of 88195874e7fffff
# found neighbors of 88195874e7fffff with 1
# searching for neighbor of 8819582985fffff
# found neighbors of 8819582985fffff with 12
# searching for neighbor of 8819586561fffff
# found neighbors of 8819586561fffff with 14
# searching for neighbor of 8819587137fffff
# found neighbors of 8819587137fffff with 18
# searching for neighbor of 8819583a6bfffff
# found neighbors of 8819583a6bfffff with 4
# searching for neighbor of 8819587131fffff
# found neighbors of 8819587131fffff with 18
# ...
# searching for neighbor of 871958620ffffff
# found neighbors of 871958620ffffff with 3
# searching for neighbor of 8719583aaffffff
# found neighbors of 8719583aaffffff with 3
# searching for neighbor of 871958385ffffff
# found neighbors of 871958385ffffff with 2
# searching for neighbor of 87195839effffff
# found neighbors of 87195839effffff with 0
# searching for neighbor of 871958623ffffff
# found neighbors of 871958623ffffff with 4
# searching for neighbor of 871958708ffffff
# found neighbors of 871958708ffffff with 2
# searching for neighbor of 871958600ffffff
# found neighbors of 871958600ffffff with 6
# searching for neighbor of 871958729ffffff
# found neighbors of 871958729ffffff with 2
# searching for neighbor of 87195839bffffff
# found neighbors of 87195839bffffff with 2
# searching for neighbor of 871958394ffffff
# found neighbors of 871958394ffffff with 0
# searching for neighbor of 87195871bffffff
# found neighbors of 87195871bffffff with 5
# searching for neighbor of 871958609ffffff
# found neighbors of 871958609ffffff with 4
# searching for neighbor of 871958663ffffff
# found neighbors of 871958663ffffff with 2
# searching for neighbor of 8719580d9ffffff
# found neighbors of 8719580d9ffffff with 1
# searching for neighbor of 871958661ffffff
# found neighbors of 871958661ffffff with 2
# searching for neighbor of 871958399ffffff
# found neighbors of 871958399ffffff with 1
# searching for neighbor of 8719586e3ffffff
# found neighbors of 8719586e3ffffff with 8
# searching for neighbor of 871958666ffffff
# found neighbors of 871958666ffffff with 0
# searching for neighbor of 871958752ffffff
# found neighbors of 871958752ffffff with 2
# searching for neighbor of 871958701ffffff
# found neighbors of 871958701ffffff with 3
# searching for neighbor of 871958669ffffff
# found neighbors of 871958669ffffff with 5
# searching for neighbor of 871958633ffffff
# found neighbors of 871958633ffffff with 6
# searching for neighbor of 871958761ffffff
# found neighbors of 871958761ffffff with 0
# searching for neighbor of 8719582aaffffff
# found neighbors of 8719582aaffffff with 0
# searching for neighbor of 8719580daffffff
# found neighbors of 8719580daffffff with 2
# searching for neighbor of 87195871cffffff
# found neighbors of 87195871cffffff with 5
# searching for neighbor of 871958766ffffff
# found neighbors of 871958766ffffff with 0
# searching for neighbor of 87195870effffff
# found neighbors of 87195870effffff with 3
# searching for neighbor of 871958760ffffff
# found neighbors of 871958760ffffff with 1
# searching for neighbor of 8719580dbffffff
# found neighbors of 8719580dbffffff with 1
# searching for neighbor of 871958284ffffff
# found neighbors of 871958284ffffff with 2
# searching for neighbor of 8719586ecffffff
# found neighbors of 8719586ecffffff with 7
# searching for neighbor of 871958741ffffff
# found neighbors of 871958741ffffff with 2
# searching for neighbor of 871958296ffffff
# found neighbors of 871958296ffffff with 2
# searching for neighbor of 871958769ffffff
# found neighbors of 871958769ffffff with 0
# searching for neighbor of 871958384ffffff
# found neighbors of 871958384ffffff with 1
# searching for neighbor of 87195870dffffff
# found neighbors of 87195870dffffff with 1
# searching for neighbor of 87195862affffff
# found neighbors of 87195862affffff with 5
# searching for neighbor of 871958713ffffff
# found neighbors of 871958713ffffff with 7
# searching for neighbor of 87195865cffffff
# found neighbors of 87195865cffffff with 5
# searching for neighbor of 8719582a4ffffff
# found neighbors of 8719582a4ffffff with 2
# searching for neighbor of 871958764ffffff
# found neighbors of 871958764ffffff with 1
# searching for neighbor of 8719580c8ffffff
# found neighbors of 8719580c8ffffff with 0
# searching for neighbor of 87195866cffffff
# found neighbors of 87195866cffffff with 3
# searching for neighbor of 8719580cdffffff
# found neighbors of 8719580cdffffff with 0
# searching for neighbor of 871958718ffffff
# found neighbors of 871958718ffffff with 5
# searching for neighbor of 87195870bffffff
# found neighbors of 87195870bffffff with 2
# searching for neighbor of 8719582b3ffffff
# found neighbors of 8719582b3ffffff with 1
# searching for neighbor of 871958283ffffff
# found neighbors of 871958283ffffff with 2
# searching for neighbor of 8719586e4ffffff
# found neighbors of 8719586e4ffffff with 6
# searching for neighbor of 871958745ffffff
# found neighbors of 871958745ffffff with 1
# searching for neighbor of 87195828effffff
# found neighbors of 87195828effffff with 2
# searching for neighbor of 871958282ffffff
# found neighbors of 871958282ffffff with 3
# searching for neighbor of 871958630ffffff
# found neighbors of 871958630ffffff with 6
# searching for neighbor of 8719582b0ffffff
# found neighbors of 8719582b0ffffff with 1
# searching for neighbor of 871958635ffffff
# found neighbors of 871958635ffffff with 5
# searching for neighbor of 87195871dffffff
# found neighbors of 87195871dffffff with 4
# searching for neighbor of 8719582a5ffffff
# found neighbors of 8719582a5ffffff with 3
# searching for neighbor of 871958744ffffff
# found neighbors of 871958744ffffff with 2
# searching for neighbor of 871958740ffffff
# found neighbors of 871958740ffffff with 1
# searching for neighbor of 871958621ffffff
# found neighbors of 871958621ffffff with 3
# searching for neighbor of 871958631ffffff
# found neighbors of 871958631ffffff with 5
# searching for neighbor of 8719586e6ffffff
# found neighbors of 8719586e6ffffff with 7
# searching for neighbor of 871958765ffffff
# found neighbors of 871958765ffffff with 0
# searching for neighbor of 871958645ffffff
# found neighbors of 871958645ffffff with 3
# searching for neighbor of 871958703ffffff
# found neighbors of 871958703ffffff with 4
# searching for neighbor of 87195866affffff
# found neighbors of 87195866affffff with 4
# searching for neighbor of 871958662ffffff
# found neighbors of 871958662ffffff with 1
# searching for neighbor of 871958749ffffff
# found neighbors of 871958749ffffff with 1
# searching for neighbor of 871958748ffffff
# found neighbors of 871958748ffffff with 1
# searching for neighbor of 871958619ffffff
# found neighbors of 871958619ffffff with 7
# searching for neighbor of 87195875cffffff
# found neighbors of 87195875cffffff with 1
# searching for neighbor of 8719586e8ffffff
# found neighbors of 8719586e8ffffff with 8
# searching for neighbor of 871958608ffffff
# found neighbors of 871958608ffffff with 5
# searching for neighbor of 8719583b5ffffff
# found neighbors of 8719583b5ffffff with 0
# searching for neighbor of 871958604ffffff
# found neighbors of 871958604ffffff with 5
# searching for neighbor of 871958058ffffff
# found neighbors of 871958058ffffff with 1
# searching for neighbor of 871958644ffffff
# found neighbors of 871958644ffffff with 2
# searching for neighbor of 87195875affffff
# found neighbors of 87195875affffff with 2
# searching for neighbor of 871958629ffffff
# found neighbors of 871958629ffffff with 3
# searching for neighbor of 871958388ffffff
# found neighbors of 871958388ffffff with 2
# searching for neighbor of 8719583a0ffffff
# found neighbors of 8719583a0ffffff with 2
# searching for neighbor of 87195875dffffff
# found neighbors of 87195875dffffff with 1
# searching for neighbor of 871958671ffffff
# found neighbors of 871958671ffffff with 2
# searching for neighbor of 87195805dffffff
# found neighbors of 87195805dffffff with 0
# searching for neighbor of 871958624ffffff
# found neighbors of 871958624ffffff with 3
# searching for neighbor of 871958290ffffff
# found neighbors of 871958290ffffff with 2
# searching for neighbor of 87195829cffffff
# found neighbors of 87195829cffffff with 3
# searching for neighbor of 8719586edffffff
# found neighbors of 8719586edffffff with 7
# searching for neighbor of 871958294ffffff
# found neighbors of 871958294ffffff with 1
# searching for neighbor of 871958702ffffff
# found neighbors of 871958702ffffff with 5
# searching for neighbor of 8719582a6ffffff
# found neighbors of 8719582a6ffffff with 2
# searching for neighbor of 8719580d8ffffff
# found neighbors of 8719580d8ffffff with 2
# searching for neighbor of 871958292ffffff
# found neighbors of 871958292ffffff with 3
# searching for neighbor of 87195838bffffff
# found neighbors of 87195838bffffff with 2
# searching for neighbor of 871958625ffffff
# found neighbors of 871958625ffffff with 2
# searching for neighbor of 871958675ffffff
# found neighbors of 871958675ffffff with 1
# searching for neighbor of 87195829effffff
# found neighbors of 87195829effffff with 4
# searching for neighbor of 8719583b1ffffff
# found neighbors of 8719583b1ffffff with 0
# searching for neighbor of 871958646ffffff
# found neighbors of 871958646ffffff with 3
# searching for neighbor of 871958773ffffff
# found neighbors of 871958773ffffff with 1
# searching for neighbor of 87195870cffffff
# found neighbors of 87195870cffffff with 2
# searching for neighbor of 871958665ffffff
# found neighbors of 871958665ffffff with 2
# searching for neighbor of 871958395ffffff
# found neighbors of 871958395ffffff with 0
# searching for neighbor of 8719582b4ffffff
# found neighbors of 8719582b4ffffff with 1
# searching for neighbor of 8719582a8ffffff
# found neighbors of 8719582a8ffffff with 1
# searching for neighbor of 87195860effffff
# found neighbors of 87195860effffff with 6
# searching for neighbor of 871958293ffffff
# found neighbors of 871958293ffffff with 3
# searching for neighbor of 87195870affffff
# found neighbors of 87195870affffff with 3
# searching for neighbor of 871958396ffffff
# found neighbors of 871958396ffffff with 0
# searching for neighbor of 87195860bffffff
# found neighbors of 87195860bffffff with 5
# searching for neighbor of 8719580ddffffff
# found neighbors of 8719580ddffffff with 1
# searching for neighbor of 871958753ffffff
# found neighbors of 871958753ffffff with 2
# searching for neighbor of 8719583a6ffffff
# found neighbors of 8719583a6ffffff with 1
# searching for neighbor of 8719582b2ffffff
# found neighbors of 8719582b2ffffff with 0
# searching for neighbor of 871958670ffffff
# found neighbors of 871958670ffffff with 2
# searching for neighbor of 87195829dffffff
# found neighbors of 87195829dffffff with 3
# searching for neighbor of 871958674ffffff
# found neighbors of 871958674ffffff with 2
# searching for neighbor of 871958389ffffff
# found neighbors of 871958389ffffff with 3
# searching for neighbor of 871958676ffffff
# found neighbors of 871958676ffffff with 3
# searching for neighbor of 87195874bffffff
# found neighbors of 87195874bffffff with 1
# searching for neighbor of 8719587a9ffffff
# found neighbors of 8719587a9ffffff with 7
# searching for neighbor of 87195805affffff
# found neighbors of 87195805affffff with 2
# searching for neighbor of 8719582a3ffffff
# found neighbors of 8719582a3ffffff with 2
# searching for neighbor of 871958774ffffff
# found neighbors of 871958774ffffff with 1
# searching for neighbor of 871958295ffffff
# found neighbors of 871958295ffffff with 2
# searching for neighbor of 871958768ffffff
# found neighbors of 871958768ffffff with 1
# searching for neighbor of 871958381ffffff
# found neighbors of 871958381ffffff with 2
# searching for neighbor of 871958660ffffff
# found neighbors of 871958660ffffff with 1
# searching for neighbor of 871958641ffffff
# found neighbors of 871958641ffffff with 4
# searching for neighbor of 871958390ffffff
# found neighbors of 871958390ffffff with 0
# searching for neighbor of 8719583b4ffffff
# found neighbors of 8719583b4ffffff with 1
# searching for neighbor of 8719582b5ffffff
# found neighbors of 8719582b5ffffff with 2
# searching for neighbor of 8719580dcffffff
# found neighbors of 8719580dcffffff with 2
# searching for neighbor of 871958213ffffff
# found neighbors of 871958213ffffff with 3
# searching for neighbor of 8719582abffffff
# found neighbors of 8719582abffffff with 1
# searching for neighbor of 871958711ffffff
# found neighbors of 871958711ffffff with 6
# searching for neighbor of 871958383ffffff
# found neighbors of 871958383ffffff with 1
# searching for neighbor of 8719587adffffff
# found neighbors of 8719587adffffff with 7
# searching for neighbor of 871958298ffffff
# found neighbors of 871958298ffffff with 4
# searching for neighbor of 871958280ffffff
# found neighbors of 871958280ffffff with 2
# searching for neighbor of 871958755ffffff
# found neighbors of 871958755ffffff with 1
# searching for neighbor of 871958776ffffff
# found neighbors of 871958776ffffff with 1
# searching for neighbor of 8719582b1ffffff
# found neighbors of 8719582b1ffffff with 2
# searching for neighbor of 8719580ccffffff
# found neighbors of 8719580ccffffff with 0
# searching for neighbor of 8719586c5ffffff
# found neighbors of 8719586c5ffffff with 9
# searching for neighbor of 871958622ffffff
# found neighbors of 871958622ffffff with 4
# searching for neighbor of 87195874affffff
# found neighbors of 87195874affffff with 0
# searching for neighbor of 87195860affffff
# found neighbors of 87195860affffff with 6
# searching for neighbor of 8719580eaffffff
# found neighbors of 8719580eaffffff with 1
# searching for neighbor of 871958758ffffff
# found neighbors of 871958758ffffff with 2
# searching for neighbor of 871958216ffffff
# found neighbors of 871958216ffffff with 3
# searching for neighbor of 8719586e5ffffff
# found neighbors of 8719586e5ffffff with 6
# searching for neighbor of 87195866effffff
# found neighbors of 87195866effffff with 3
# searching for neighbor of 871958770ffffff
# found neighbors of 871958770ffffff with 1
# searching for neighbor of 871958285ffffff
# found neighbors of 871958285ffffff with 1
# searching for neighbor of 871958719ffffff
# found neighbors of 871958719ffffff with 4
# searching for neighbor of 8719582a9ffffff
# found neighbors of 8719582a9ffffff with 2
# searching for neighbor of 87195838affffff
# found neighbors of 87195838affffff with 1
# searching for neighbor of 87195860dffffff
# found neighbors of 87195860dffffff with 4
# searching for neighbor of 87195871affffff
# found neighbors of 87195871affffff with 6
# searching for neighbor of 8719580ceffffff
# found neighbors of 8719580ceffffff with 0
# searching for neighbor of 871958386ffffff
# found neighbors of 871958386ffffff with 0
# searching for neighbor of 8719582a2ffffff
# found neighbors of 8719582a2ffffff with 3
# searching for neighbor of 871958628ffffff
# found neighbors of 871958628ffffff with 4
# searching for neighbor of 871958651ffffff
# found neighbors of 871958651ffffff with 5
# searching for neighbor of 871958759ffffff
# found neighbors of 871958759ffffff with 1
# searching for neighbor of 87195876bffffff
# found neighbors of 87195876bffffff with 1
# searching for neighbor of 87195838cffffff
# found neighbors of 87195838cffffff with 2
# searching for neighbor of 87195874dffffff
# found neighbors of 87195874dffffff with 1
# searching for neighbor of 871958212ffffff
# found neighbors of 871958212ffffff with 3
# searching for neighbor of 8719582b6ffffff
# found neighbors of 8719582b6ffffff with 1
# searching for neighbor of 871958626ffffff
# found neighbors of 871958626ffffff with 4
# searching for neighbor of 871958775ffffff
# found neighbors of 871958775ffffff with 0
# searching for neighbor of 871958286ffffff
# found neighbors of 871958286ffffff with 2
# searching for neighbor of 8719580cbffffff
# found neighbors of 8719580cbffffff with 0
# searching for neighbor of 87195876affffff
# found neighbors of 87195876affffff with 1
# searching for neighbor of 8719583b0ffffff
# found neighbors of 8719583b0ffffff with 0
# searching for neighbor of 871958291ffffff
# found neighbors of 871958291ffffff with 3
# searching for neighbor of 871958602ffffff
# found neighbors of 871958602ffffff with 7
# searching for neighbor of 8719583b2ffffff
# found neighbors of 8719583b2ffffff with 0
# searching for neighbor of 8719583b3ffffff
# found neighbors of 8719583b3ffffff with 0
# searching for neighbor of 87195875effffff
# found neighbors of 87195875effffff with 2
# searching for neighbor of 871958059ffffff
# found neighbors of 871958059ffffff with 1
# searching for neighbor of 8719580c1ffffff
# found neighbors of 8719580c1ffffff with 1
# searching for neighbor of 87195875bffffff
# found neighbors of 87195875bffffff with 1
# searching for neighbor of 87195861dffffff
# found neighbors of 87195861dffffff with 7
# searching for neighbor of 871958382ffffff
# found neighbors of 871958382ffffff with 0
# searching for neighbor of 871958654ffffff
# found neighbors of 871958654ffffff with 4
# searching for neighbor of 87195872affffff
# found neighbors of 87195872affffff with 3

# %%
traffic_analysis_data =  ult.to_camel_case(raw_traffic_data.query('Count_date>=@period_start and Count_date<@period_end').copy().sort_values('Count_date'))
# traffic_analysis_data
date_list = list(np.unique(traffic_analysis_data['CountDate']))
avg_2022_traffic = traffic_analysis_data['AllMotorVehicles'].mean()
# date_list

# %% [markdown]
# `traffic_analysis_data` contains all monitored traffic in 2023. The sampling size is 50 days within 2022, usually taken 2 times per week, one of the day is usualy Monday.

# %% [markdown]
# ## Get Daily Active Station Data

# %%
# raw_station_data
raw_simulation_station_data = dpr.extract_station_data(simulation_res=simulation_level)
station_analysis_data = pd.DataFrame()
temp = pd.DataFrame()

for simday in date_list:
    temp = raw_simulation_station_data.query('DateCreated <= @simday and HexLevel == @simulation_level').copy()
    temp['Date'] = simday
    station_analysis_data = pd.concat([station_analysis_data, temp])

# station_analysis_data.to_csv('simulation/output/station_2022.csv')
# station_analysis_data
# Out:
# searching for neighbor of 85195877fffffff
# found neighbors of 85195877fffffff with 0
# searching for neighbor of 8519583bfffffff
# found neighbors of 8519583bfffffff with 0
# searching for neighbor of 8519582bfffffff
# found neighbors of 8519582bfffffff with 0
# searching for neighbor of 85195863fffffff
# found neighbors of 85195863fffffff with 1
# searching for neighbor of 85195873fffffff
# found neighbors of 85195873fffffff with 1
# searching for neighbor of 85195867fffffff
# found neighbors of 85195867fffffff with 0
# searching for neighbor of 8619580cfffffff
# found neighbors of 8619580cfffffff with 0
# searching for neighbor of 861958397ffffff
# found neighbors of 861958397ffffff with 0
# searching for neighbor of 86195862fffffff
# found neighbors of 86195862fffffff with 1
# searching for neighbor of 861958677ffffff
# found neighbors of 861958677ffffff with 1
# searching for neighbor of 861958647ffffff
# found neighbors of 861958647ffffff with 1
# searching for neighbor of 861958657ffffff
# found neighbors of 861958657ffffff with 2
# searching for neighbor of 8619582a7ffffff
# found neighbors of 8619582a7ffffff with 1
# searching for neighbor of 86195875fffffff
# found neighbors of 86195875fffffff with 1
# searching for neighbor of 8619586e7ffffff
# found neighbors of 8619586e7ffffff with 3
# searching for neighbor of 86195866fffffff
# found neighbors of 86195866fffffff with 1
# searching for neighbor of 861958607ffffff
# found neighbors of 861958607ffffff with 2
# searching for neighbor of 861958667ffffff
# found neighbors of 861958667ffffff with 0
# searching for neighbor of 86195829fffffff
# found neighbors of 86195829fffffff with 2
# searching for neighbor of 861958707ffffff
# found neighbors of 861958707ffffff with 2
# searching for neighbor of 861958627ffffff
# found neighbors of 861958627ffffff with 1
# searching for neighbor of 86195839fffffff
# found neighbors of 86195839fffffff with 0
# searching for neighbor of 861958757ffffff
# found neighbors of 861958757ffffff with 0
# searching for neighbor of 86195860fffffff
# found neighbors of 86195860fffffff with 2
# searching for neighbor of 8619586efffffff
# found neighbors of 8619586efffffff with 3
# searching for neighbor of 8619580dfffffff
# found neighbors of 8619580dfffffff with 1
# searching for neighbor of 8619583a7ffffff
# found neighbors of 8619583a7ffffff with 1
# searching for neighbor of 861958637ffffff
# found neighbors of 861958637ffffff with 2
# searching for neighbor of 86195805fffffff
# found neighbors of 86195805fffffff with 0
# searching for neighbor of 8619582b7ffffff
# found neighbors of 8619582b7ffffff with 0
# searching for neighbor of 86195872fffffff
# found neighbors of 86195872fffffff with 1
# searching for neighbor of 86195871fffffff
# found neighbors of 86195871fffffff with 2
# searching for neighbor of 861958387ffffff
# found neighbors of 861958387ffffff with 0
# searching for neighbor of 861958297ffffff
# found neighbors of 861958297ffffff with 1
# searching for neighbor of 86195874fffffff
# found neighbors of 86195874fffffff with 0
# searching for neighbor of 861958747ffffff
# found neighbors of 861958747ffffff with 1
# searching for neighbor of 86195870fffffff
# found neighbors of 86195870fffffff with 1
# searching for neighbor of 861958287ffffff
# found neighbors of 861958287ffffff with 1
# searching for neighbor of 8619582afffffff
# found neighbors of 8619582afffffff with 0
# searching for neighbor of 861958777ffffff
# found neighbors of 861958777ffffff with 0
# searching for neighbor of 8619583b7ffffff
# found neighbors of 8619583b7ffffff with 0
# searching for neighbor of 86195838fffffff
# found neighbors of 86195838fffffff with 1
# searching for neighbor of 86195876fffffff
# found neighbors of 86195876fffffff with 0
# searching for neighbor of 861958767ffffff
# found neighbors of 861958767ffffff with 0
# searching for neighbor of 87195872dffffff
# found neighbors of 87195872dffffff with 3
# searching for neighbor of 871958709ffffff
# found neighbors of 871958709ffffff with 1
# searching for neighbor of 87195862dffffff
# found neighbors of 87195862dffffff with 3
# searching for neighbor of 8719582adffffff
# found neighbors of 8719582adffffff with 2
# searching for neighbor of 871958281ffffff
# found neighbors of 871958281ffffff with 1
# searching for neighbor of 871958771ffffff
# found neighbors of 871958771ffffff with 1
# searching for neighbor of 87195871effffff
# found neighbors of 87195871effffff with 6
# searching for neighbor of 871958742ffffff
# found neighbors of 871958742ffffff with 0
# searching for neighbor of 8719583b6ffffff
# found neighbors of 8719583b6ffffff with 1
# searching for neighbor of 871958643ffffff
# found neighbors of 871958643ffffff with 4
# searching for neighbor of 8719580e9ffffff
# found neighbors of 8719580e9ffffff with 1
# searching for neighbor of 871958392ffffff
# found neighbors of 871958392ffffff with 0
# searching for neighbor of 8719582a1ffffff
# found neighbors of 8719582a1ffffff with 2
# searching for neighbor of 871958743ffffff
# found neighbors of 871958743ffffff with 1
# searching for neighbor of 871958640ffffff
# found neighbors of 871958640ffffff with 3
# searching for neighbor of 87195862effffff
# found neighbors of 87195862effffff with 4
# searching for neighbor of 8719586e1ffffff
# found neighbors of 8719586e1ffffff with 7
# searching for neighbor of 871958746ffffff
# found neighbors of 871958746ffffff with 1
# searching for neighbor of 871958642ffffff
# found neighbors of 871958642ffffff with 4
# searching for neighbor of 87195876cffffff
# found neighbors of 87195876cffffff with 0
# searching for neighbor of 871958673ffffff
# found neighbors of 871958673ffffff with 3
# searching for neighbor of 8719580deffffff
# found neighbors of 8719580deffffff with 3
# searching for neighbor of 871958763ffffff
# found neighbors of 871958763ffffff with 1
# searching for neighbor of 871958672ffffff
# found neighbors of 871958672ffffff with 3
# searching for neighbor of 8719582acffffff
# found neighbors of 8719582acffffff with 2
# searching for neighbor of 871958634ffffff
# found neighbors of 871958634ffffff with 6
# searching for neighbor of 8719580c9ffffff
# found neighbors of 8719580c9ffffff with 0
# searching for neighbor of 87195829affffff
# found neighbors of 87195829affffff with 5
# searching for neighbor of 87195866dffffff
# found neighbors of 87195866dffffff with 4
# searching for neighbor of 87195862cffffff
# found neighbors of 87195862cffffff with 3
# searching for neighbor of 871958754ffffff
# found neighbors of 871958754ffffff with 0
# searching for neighbor of 871958650ffffff
# found neighbors of 871958650ffffff with 5
# searching for neighbor of 871958601ffffff
# found neighbors of 871958601ffffff with 6
# searching for neighbor of 871958653ffffff
# found neighbors of 871958653ffffff with 6
# searching for neighbor of 871958700ffffff
# found neighbors of 871958700ffffff with 4
# searching for neighbor of 87195860cffffff
# found neighbors of 87195860cffffff with 5
# searching for neighbor of 87195839cffffff
# found neighbors of 87195839cffffff with 1
# searching for neighbor of 8719580ebffffff
# found neighbors of 8719580ebffffff with 0
# searching for neighbor of 871958606ffffff
# found neighbors of 871958606ffffff with 6
# searching for neighbor of 8719586e0ffffff
# found neighbors of 8719586e0ffffff with 7
# searching for neighbor of 871958728ffffff
# found neighbors of 871958728ffffff with 3
# searching for neighbor of 871958664ffffff
# found neighbors of 871958664ffffff with 1
# searching for neighbor of 87195805bffffff
# found neighbors of 87195805bffffff with 1
# searching for neighbor of 871958380ffffff
# found neighbors of 871958380ffffff with 1
# searching for neighbor of 871958605ffffff
# found neighbors of 871958605ffffff with 5
# searching for neighbor of 87195874cffffff
# found neighbors of 87195874cffffff with 2
# searching for neighbor of 871958762ffffff
# found neighbors of 871958762ffffff with 1
# searching for neighbor of 8719580caffffff
# found neighbors of 8719580caffffff with 0
# searching for neighbor of 87195872bffffff
# found neighbors of 87195872bffffff with 2
# searching for neighbor of 87195838effffff
# found neighbors of 87195838effffff with 1
# searching for neighbor of 87195862bffffff
# found neighbors of 87195862bffffff with 4
# searching for neighbor of 8719583a3ffffff
# found neighbors of 8719583a3ffffff with 2
# searching for neighbor of 871958750ffffff
# found neighbors of 871958750ffffff with 1
# searching for neighbor of 871958756ffffff
# found neighbors of 871958756ffffff with 1
# searching for neighbor of 87195876dffffff
# found neighbors of 87195876dffffff with 0
# searching for neighbor of 87195828cffffff
# found neighbors of 87195828cffffff with 1
# searching for neighbor of 87195865effffff
# found neighbors of 87195865effffff with 6
# searching for neighbor of 871958603ffffff
# found neighbors of 871958603ffffff with 7
# searching for neighbor of 8719586eeffffff
# found neighbors of 8719586eeffffff with 8
# searching for neighbor of 87195839dffffff
# found neighbors of 87195839dffffff with 0
# searching for neighbor of 871958655ffffff
# found neighbors of 871958655ffffff with 4
# searching for neighbor of 871958391ffffff
# found neighbors of 871958391ffffff with 1
# searching for neighbor of 87195839affffff
# found neighbors of 87195839affffff with 1
# searching for neighbor of 871958652ffffff
# found neighbors of 871958652ffffff with 6
# searching for neighbor of 87195876effffff
# found neighbors of 87195876effffff with 0
# searching for neighbor of 87195874effffff
# found neighbors of 87195874effffff with 1
# searching for neighbor of 871958656ffffff
# found neighbors of 871958656ffffff with 5
# searching for neighbor of 87195861cffffff
# found neighbors of 87195861cffffff with 8
# searching for neighbor of 8719582aeffffff
# found neighbors of 8719582aeffffff with 1
# searching for neighbor of 871958398ffffff
# found neighbors of 871958398ffffff with 1
# searching for neighbor of 871958751ffffff
# found neighbors of 871958751ffffff with 1
# searching for neighbor of 871958668ffffff
# found neighbors of 871958668ffffff with 4
# searching for neighbor of 871958772ffffff
# found neighbors of 871958772ffffff with 0
# searching for neighbor of 8719583a2ffffff
# found neighbors of 8719583a2ffffff with 1
# searching for neighbor of 871958393ffffff
# found neighbors of 871958393ffffff with 0
# searching for neighbor of 8719586eaffffff
# found neighbors of 8719586eaffffff with 9
# searching for neighbor of 8719582a0ffffff
# found neighbors of 8719582a0ffffff with 3
# searching for neighbor of 8719580c3ffffff
# found neighbors of 8719580c3ffffff with 1
# searching for neighbor of 871958620ffffff
# found neighbors of 871958620ffffff with 3
# searching for neighbor of 8719583aaffffff
# found neighbors of 8719583aaffffff with 3
# searching for neighbor of 871958385ffffff
# found neighbors of 871958385ffffff with 2
# searching for neighbor of 87195839effffff
# found neighbors of 87195839effffff with 0
# searching for neighbor of 871958623ffffff
# found neighbors of 871958623ffffff with 4
# searching for neighbor of 871958708ffffff
# found neighbors of 871958708ffffff with 2
# searching for neighbor of 871958600ffffff
# found neighbors of 871958600ffffff with 6
# searching for neighbor of 871958729ffffff
# found neighbors of 871958729ffffff with 2
# searching for neighbor of 87195839bffffff
# found neighbors of 87195839bffffff with 2
# searching for neighbor of 871958394ffffff
# found neighbors of 871958394ffffff with 0
# searching for neighbor of 87195871bffffff
# found neighbors of 87195871bffffff with 5
# searching for neighbor of 871958609ffffff
# found neighbors of 871958609ffffff with 4
# searching for neighbor of 871958663ffffff
# found neighbors of 871958663ffffff with 2
# searching for neighbor of 8719580d9ffffff
# found neighbors of 8719580d9ffffff with 1
# searching for neighbor of 871958661ffffff
# found neighbors of 871958661ffffff with 2
# searching for neighbor of 871958399ffffff
# found neighbors of 871958399ffffff with 1
# searching for neighbor of 8719586e3ffffff
# found neighbors of 8719586e3ffffff with 8
# searching for neighbor of 871958666ffffff
# found neighbors of 871958666ffffff with 0
# searching for neighbor of 871958752ffffff
# found neighbors of 871958752ffffff with 2
# searching for neighbor of 871958701ffffff
# found neighbors of 871958701ffffff with 3
# searching for neighbor of 871958669ffffff
# found neighbors of 871958669ffffff with 5
# searching for neighbor of 871958633ffffff
# found neighbors of 871958633ffffff with 6
# searching for neighbor of 871958761ffffff
# found neighbors of 871958761ffffff with 0
# searching for neighbor of 8719582aaffffff
# found neighbors of 8719582aaffffff with 0
# searching for neighbor of 8719580daffffff
# found neighbors of 8719580daffffff with 2
# searching for neighbor of 87195871cffffff
# found neighbors of 87195871cffffff with 5
# searching for neighbor of 871958766ffffff
# found neighbors of 871958766ffffff with 0
# searching for neighbor of 87195870effffff
# found neighbors of 87195870effffff with 3
# searching for neighbor of 871958760ffffff
# found neighbors of 871958760ffffff with 1
# searching for neighbor of 8719580dbffffff
# found neighbors of 8719580dbffffff with 1
# searching for neighbor of 871958284ffffff
# found neighbors of 871958284ffffff with 2
# searching for neighbor of 8719586ecffffff
# found neighbors of 8719586ecffffff with 7
# searching for neighbor of 871958741ffffff
# found neighbors of 871958741ffffff with 2
# searching for neighbor of 871958296ffffff
# found neighbors of 871958296ffffff with 2
# searching for neighbor of 871958769ffffff
# found neighbors of 871958769ffffff with 0
# searching for neighbor of 871958384ffffff
# found neighbors of 871958384ffffff with 1
# searching for neighbor of 87195870dffffff
# found neighbors of 87195870dffffff with 1
# searching for neighbor of 87195862affffff
# found neighbors of 87195862affffff with 5
# searching for neighbor of 871958713ffffff
# found neighbors of 871958713ffffff with 7
# searching for neighbor of 87195865cffffff
# found neighbors of 87195865cffffff with 5
# searching for neighbor of 8719582a4ffffff
# found neighbors of 8719582a4ffffff with 2
# searching for neighbor of 871958764ffffff
# found neighbors of 871958764ffffff with 1
# searching for neighbor of 8719580c8ffffff
# found neighbors of 8719580c8ffffff with 0
# searching for neighbor of 87195866cffffff
# found neighbors of 87195866cffffff with 3
# searching for neighbor of 8719580cdffffff
# found neighbors of 8719580cdffffff with 0
# searching for neighbor of 871958718ffffff
# found neighbors of 871958718ffffff with 5
# searching for neighbor of 87195870bffffff
# found neighbors of 87195870bffffff with 2
# searching for neighbor of 8719582b3ffffff
# found neighbors of 8719582b3ffffff with 1
# searching for neighbor of 871958283ffffff
# found neighbors of 871958283ffffff with 2
# searching for neighbor of 8719586e4ffffff
# found neighbors of 8719586e4ffffff with 6
# searching for neighbor of 871958745ffffff
# found neighbors of 871958745ffffff with 1
# searching for neighbor of 87195828effffff
# found neighbors of 87195828effffff with 2
# searching for neighbor of 871958282ffffff
# found neighbors of 871958282ffffff with 3
# searching for neighbor of 871958630ffffff
# found neighbors of 871958630ffffff with 6
# searching for neighbor of 8719582b0ffffff
# found neighbors of 8719582b0ffffff with 1
# searching for neighbor of 871958635ffffff
# found neighbors of 871958635ffffff with 5
# searching for neighbor of 87195871dffffff
# found neighbors of 87195871dffffff with 4
# searching for neighbor of 8719582a5ffffff
# found neighbors of 8719582a5ffffff with 3
# searching for neighbor of 871958744ffffff
# found neighbors of 871958744ffffff with 2
# searching for neighbor of 871958740ffffff
# found neighbors of 871958740ffffff with 1
# searching for neighbor of 871958621ffffff
# found neighbors of 871958621ffffff with 3
# searching for neighbor of 871958631ffffff
# found neighbors of 871958631ffffff with 5
# searching for neighbor of 8719586e6ffffff
# found neighbors of 8719586e6ffffff with 7
# searching for neighbor of 871958765ffffff
# found neighbors of 871958765ffffff with 0
# searching for neighbor of 871958645ffffff
# found neighbors of 871958645ffffff with 3
# searching for neighbor of 871958703ffffff
# found neighbors of 871958703ffffff with 4
# searching for neighbor of 87195866affffff
# found neighbors of 87195866affffff with 4
# searching for neighbor of 871958662ffffff
# found neighbors of 871958662ffffff with 1
# searching for neighbor of 871958749ffffff
# found neighbors of 871958749ffffff with 1
# searching for neighbor of 871958748ffffff
# found neighbors of 871958748ffffff with 1
# searching for neighbor of 871958619ffffff
# found neighbors of 871958619ffffff with 7
# searching for neighbor of 87195875cffffff
# found neighbors of 87195875cffffff with 1
# searching for neighbor of 8719586e8ffffff
# found neighbors of 8719586e8ffffff with 8
# searching for neighbor of 871958608ffffff
# found neighbors of 871958608ffffff with 5
# searching for neighbor of 8719583b5ffffff
# found neighbors of 8719583b5ffffff with 0
# searching for neighbor of 871958604ffffff
# found neighbors of 871958604ffffff with 5
# searching for neighbor of 871958058ffffff
# found neighbors of 871958058ffffff with 1
# searching for neighbor of 871958644ffffff
# found neighbors of 871958644ffffff with 2
# searching for neighbor of 87195875affffff
# found neighbors of 87195875affffff with 2
# searching for neighbor of 871958629ffffff
# found neighbors of 871958629ffffff with 3
# searching for neighbor of 871958388ffffff
# found neighbors of 871958388ffffff with 2
# searching for neighbor of 8719583a0ffffff
# found neighbors of 8719583a0ffffff with 2
# searching for neighbor of 87195875dffffff
# found neighbors of 87195875dffffff with 1
# searching for neighbor of 871958671ffffff
# found neighbors of 871958671ffffff with 2
# searching for neighbor of 87195805dffffff
# found neighbors of 87195805dffffff with 0
# searching for neighbor of 871958624ffffff
# found neighbors of 871958624ffffff with 3
# searching for neighbor of 871958290ffffff
# found neighbors of 871958290ffffff with 2
# searching for neighbor of 87195829cffffff
# found neighbors of 87195829cffffff with 3
# searching for neighbor of 8719586edffffff
# found neighbors of 8719586edffffff with 7
# searching for neighbor of 871958294ffffff
# found neighbors of 871958294ffffff with 1
# searching for neighbor of 871958702ffffff
# found neighbors of 871958702ffffff with 5
# searching for neighbor of 8719582a6ffffff
# found neighbors of 8719582a6ffffff with 2
# searching for neighbor of 8719580d8ffffff
# found neighbors of 8719580d8ffffff with 2
# searching for neighbor of 871958292ffffff
# found neighbors of 871958292ffffff with 3
# searching for neighbor of 87195838bffffff
# found neighbors of 87195838bffffff with 2
# searching for neighbor of 871958625ffffff
# found neighbors of 871958625ffffff with 2
# searching for neighbor of 871958675ffffff
# found neighbors of 871958675ffffff with 1
# searching for neighbor of 87195829effffff
# found neighbors of 87195829effffff with 4
# searching for neighbor of 8719583b1ffffff
# found neighbors of 8719583b1ffffff with 0
# searching for neighbor of 871958646ffffff
# found neighbors of 871958646ffffff with 3
# searching for neighbor of 871958773ffffff
# found neighbors of 871958773ffffff with 1
# searching for neighbor of 87195870cffffff
# found neighbors of 87195870cffffff with 2
# searching for neighbor of 871958665ffffff
# found neighbors of 871958665ffffff with 2
# searching for neighbor of 871958395ffffff
# found neighbors of 871958395ffffff with 0
# searching for neighbor of 8719582b4ffffff
# found neighbors of 8719582b4ffffff with 1
# searching for neighbor of 8719582a8ffffff
# found neighbors of 8719582a8ffffff with 1
# searching for neighbor of 87195860effffff
# found neighbors of 87195860effffff with 6
# searching for neighbor of 871958293ffffff
# found neighbors of 871958293ffffff with 3
# searching for neighbor of 87195870affffff
# found neighbors of 87195870affffff with 3
# searching for neighbor of 871958396ffffff
# found neighbors of 871958396ffffff with 0
# searching for neighbor of 87195860bffffff
# found neighbors of 87195860bffffff with 5
# searching for neighbor of 8719580ddffffff
# found neighbors of 8719580ddffffff with 1
# searching for neighbor of 871958753ffffff
# found neighbors of 871958753ffffff with 2
# searching for neighbor of 8719583a6ffffff
# found neighbors of 8719583a6ffffff with 1
# searching for neighbor of 8719582b2ffffff
# found neighbors of 8719582b2ffffff with 0
# searching for neighbor of 871958670ffffff
# found neighbors of 871958670ffffff with 2
# searching for neighbor of 87195829dffffff
# found neighbors of 87195829dffffff with 3
# searching for neighbor of 871958674ffffff
# found neighbors of 871958674ffffff with 2
# searching for neighbor of 871958389ffffff
# found neighbors of 871958389ffffff with 3
# searching for neighbor of 871958676ffffff
# found neighbors of 871958676ffffff with 3
# searching for neighbor of 87195874bffffff
# found neighbors of 87195874bffffff with 1
# searching for neighbor of 8719587a9ffffff
# found neighbors of 8719587a9ffffff with 7
# searching for neighbor of 87195805affffff
# found neighbors of 87195805affffff with 2
# searching for neighbor of 8719582a3ffffff
# found neighbors of 8719582a3ffffff with 2
# searching for neighbor of 871958774ffffff
# found neighbors of 871958774ffffff with 1
# searching for neighbor of 871958295ffffff
# found neighbors of 871958295ffffff with 2
# searching for neighbor of 871958768ffffff
# found neighbors of 871958768ffffff with 1
# searching for neighbor of 871958381ffffff
# found neighbors of 871958381ffffff with 2
# searching for neighbor of 871958660ffffff
# found neighbors of 871958660ffffff with 1
# searching for neighbor of 871958641ffffff
# found neighbors of 871958641ffffff with 4
# searching for neighbor of 871958390ffffff
# found neighbors of 871958390ffffff with 0
# searching for neighbor of 8719583b4ffffff
# found neighbors of 8719583b4ffffff with 1
# searching for neighbor of 8719582b5ffffff
# found neighbors of 8719582b5ffffff with 2
# searching for neighbor of 8719580dcffffff
# found neighbors of 8719580dcffffff with 2
# searching for neighbor of 871958213ffffff
# found neighbors of 871958213ffffff with 3
# searching for neighbor of 8719582abffffff
# found neighbors of 8719582abffffff with 1
# searching for neighbor of 871958711ffffff
# found neighbors of 871958711ffffff with 6
# searching for neighbor of 871958383ffffff
# found neighbors of 871958383ffffff with 1
# searching for neighbor of 8719587adffffff
# found neighbors of 8719587adffffff with 7
# searching for neighbor of 871958298ffffff
# found neighbors of 871958298ffffff with 4
# searching for neighbor of 871958280ffffff
# found neighbors of 871958280ffffff with 2
# searching for neighbor of 871958755ffffff
# found neighbors of 871958755ffffff with 1
# searching for neighbor of 871958776ffffff
# found neighbors of 871958776ffffff with 1
# searching for neighbor of 8719582b1ffffff
# found neighbors of 8719582b1ffffff with 2
# searching for neighbor of 8719580ccffffff
# found neighbors of 8719580ccffffff with 0
# searching for neighbor of 8719586c5ffffff
# found neighbors of 8719586c5ffffff with 9
# searching for neighbor of 871958622ffffff
# found neighbors of 871958622ffffff with 4
# searching for neighbor of 87195874affffff
# found neighbors of 87195874affffff with 0
# searching for neighbor of 87195860affffff
# found neighbors of 87195860affffff with 6
# searching for neighbor of 8719580eaffffff
# found neighbors of 8719580eaffffff with 1
# searching for neighbor of 871958758ffffff
# found neighbors of 871958758ffffff with 2
# searching for neighbor of 871958216ffffff
# found neighbors of 871958216ffffff with 3
# searching for neighbor of 8719586e5ffffff
# found neighbors of 8719586e5ffffff with 6
# searching for neighbor of 87195866effffff
# found neighbors of 87195866effffff with 3
# searching for neighbor of 871958770ffffff
# found neighbors of 871958770ffffff with 1
# searching for neighbor of 871958285ffffff
# found neighbors of 871958285ffffff with 1
# searching for neighbor of 871958719ffffff
# found neighbors of 871958719ffffff with 4
# searching for neighbor of 8719582a9ffffff
# found neighbors of 8719582a9ffffff with 2
# searching for neighbor of 87195838affffff
# found neighbors of 87195838affffff with 1
# searching for neighbor of 87195860dffffff
# found neighbors of 87195860dffffff with 4
# searching for neighbor of 87195871affffff
# found neighbors of 87195871affffff with 6
# searching for neighbor of 8719580ceffffff
# found neighbors of 8719580ceffffff with 0
# searching for neighbor of 871958386ffffff
# found neighbors of 871958386ffffff with 0
# searching for neighbor of 8719582a2ffffff
# found neighbors of 8719582a2ffffff with 3
# searching for neighbor of 871958628ffffff
# found neighbors of 871958628ffffff with 4
# searching for neighbor of 871958651ffffff
# found neighbors of 871958651ffffff with 5
# searching for neighbor of 871958759ffffff
# found neighbors of 871958759ffffff with 1
# searching for neighbor of 87195876bffffff
# found neighbors of 87195876bffffff with 1
# searching for neighbor of 87195838cffffff
# found neighbors of 87195838cffffff with 2
# searching for neighbor of 87195874dffffff
# found neighbors of 87195874dffffff with 1
# searching for neighbor of 871958212ffffff
# found neighbors of 871958212ffffff with 3
# searching for neighbor of 8719582b6ffffff
# found neighbors of 8719582b6ffffff with 1
# searching for neighbor of 871958626ffffff
# found neighbors of 871958626ffffff with 4
# searching for neighbor of 871958775ffffff
# found neighbors of 871958775ffffff with 0
# searching for neighbor of 871958286ffffff
# found neighbors of 871958286ffffff with 2
# searching for neighbor of 8719580cbffffff
# found neighbors of 8719580cbffffff with 0
# searching for neighbor of 87195876affffff
# found neighbors of 87195876affffff with 1
# searching for neighbor of 8719583b0ffffff
# found neighbors of 8719583b0ffffff with 0
# searching for neighbor of 871958291ffffff
# found neighbors of 871958291ffffff with 3
# searching for neighbor of 871958602ffffff
# found neighbors of 871958602ffffff with 7
# searching for neighbor of 8719583b2ffffff
# found neighbors of 8719583b2ffffff with 0
# searching for neighbor of 8719583b3ffffff
# found neighbors of 8719583b3ffffff with 0
# searching for neighbor of 87195875effffff
# found neighbors of 87195875effffff with 2
# searching for neighbor of 871958059ffffff
# found neighbors of 871958059ffffff with 1
# searching for neighbor of 8719580c1ffffff
# found neighbors of 8719580c1ffffff with 1
# searching for neighbor of 87195875bffffff
# found neighbors of 87195875bffffff with 1
# searching for neighbor of 87195861dffffff
# found neighbors of 87195861dffffff with 7
# searching for neighbor of 871958382ffffff
# found neighbors of 871958382ffffff with 0
# searching for neighbor of 871958654ffffff
# found neighbors of 871958654ffffff with 4
# searching for neighbor of 87195872affffff
# found neighbors of 87195872affffff with 3
# searching for neighbor of 88195862e7fffff
# found neighbors of 88195862e7fffff with 10
# searching for neighbor of 8819583837fffff
# found neighbors of 8819583837fffff with 1
# searching for neighbor of 88195870e7fffff
# found neighbors of 88195870e7fffff with 8
# searching for neighbor of 88195805ddfffff
# found neighbors of 88195805ddfffff with 2
# searching for neighbor of 881958754dfffff
# found neighbors of 881958754dfffff with 1
# searching for neighbor of 881958286dfffff
# found neighbors of 881958286dfffff with 4
# searching for neighbor of 8819583a21fffff
# found neighbors of 8819583a21fffff with 2
# searching for neighbor of 8819582b63fffff
# found neighbors of 8819582b63fffff with 2
# searching for neighbor of 8819586055fffff
# found neighbors of 8819586055fffff with 13
# searching for neighbor of 881958750bfffff
# found neighbors of 881958750bfffff with 3
# searching for neighbor of 88195829abfffff
# found neighbors of 88195829abfffff with 13
# searching for neighbor of 8819580d8bfffff
# found neighbors of 8819580d8bfffff with 4
# searching for neighbor of 88195829dbfffff
# found neighbors of 88195829dbfffff with 7
# searching for neighbor of 8819580593fffff
# found neighbors of 8819580593fffff with 3
# searching for neighbor of 88195860a5fffff
# found neighbors of 88195860a5fffff with 17
# searching for neighbor of 88195829d5fffff
# found neighbors of 88195829d5fffff with 9
# searching for neighbor of 88195839e3fffff
# found neighbors of 88195839e3fffff with 1
# searching for neighbor of 8819583995fffff
# found neighbors of 8819583995fffff with 3
# searching for neighbor of 88195876e1fffff
# found neighbors of 88195876e1fffff with 0
# searching for neighbor of 8819586401fffff
# found neighbors of 8819586401fffff with 8
# searching for neighbor of 88195866c9fffff
# found neighbors of 88195866c9fffff with 8
# searching for neighbor of 8819586625fffff
# found neighbors of 8819586625fffff with 3
# searching for neighbor of 8819582ab7fffff
# found neighbors of 8819582ab7fffff with 2
# searching for neighbor of 8819586505fffff
# found neighbors of 8819586505fffff with 14
# searching for neighbor of 8819587719fffff
# found neighbors of 8819587719fffff with 2
# searching for neighbor of 88195874b3fffff
# found neighbors of 88195874b3fffff with 5
# searching for neighbor of 8819582b0dfffff
# found neighbors of 8819582b0dfffff with 2
# searching for neighbor of 881958741dfffff
# found neighbors of 881958741dfffff with 5
# searching for neighbor of 881958390dfffff
# found neighbors of 881958390dfffff with 1
# searching for neighbor of 8819580585fffff
# found neighbors of 8819580585fffff with 4
# searching for neighbor of 88195876e7fffff
# found neighbors of 88195876e7fffff with 1
# searching for neighbor of 8819587139fffff
# found neighbors of 8819587139fffff with 18
# searching for neighbor of 88195838b9fffff
# found neighbors of 88195838b9fffff with 6
# searching for neighbor of 88195876e5fffff
# found neighbors of 88195876e5fffff with 1
# searching for neighbor of 8819586193fffff
# found neighbors of 8819586193fffff with 19
# searching for neighbor of 88195874d7fffff
# found neighbors of 88195874d7fffff with 4
# searching for neighbor of 8819587acbfffff
# found neighbors of 8819587acbfffff with 19
# searching for neighbor of 88195876a9fffff
# found neighbors of 88195876a9fffff with 1
# searching for neighbor of 8819580e93fffff
# found neighbors of 8819580e93fffff with 4
# searching for neighbor of 8819580cebfffff
# found neighbors of 8819580cebfffff with 1
# searching for neighbor of 8819580cd7fffff
# found neighbors of 8819580cd7fffff with 1
# searching for neighbor of 8819580c17fffff
# found neighbors of 8819580c17fffff with 3
# searching for neighbor of 8819582a2dfffff
# found neighbors of 8819582a2dfffff with 6
# searching for neighbor of 8819586537fffff
# found neighbors of 8819586537fffff with 16
# searching for neighbor of 881958382dfffff
# found neighbors of 881958382dfffff with 1
# searching for neighbor of 881958293bfffff
# found neighbors of 881958293bfffff with 9
# searching for neighbor of 8819582a43fffff
# found neighbors of 8819582a43fffff with 6
# searching for neighbor of 8819580587fffff
# found neighbors of 8819580587fffff with 4
# searching for neighbor of 881958642bfffff
# found neighbors of 881958642bfffff with 9
# searching for neighbor of 88195861c9fffff
# found neighbors of 88195861c9fffff with 19
# searching for neighbor of 8819587611fffff
# found neighbors of 8819587611fffff with 1
# searching for neighbor of 8819583933fffff
# found neighbors of 8819583933fffff with 1
# searching for neighbor of 881958674bfffff
# found neighbors of 881958674bfffff with 5
# searching for neighbor of 88195871e1fffff
# found neighbors of 88195871e1fffff with 15
# searching for neighbor of 8819583a33fffff
# found neighbors of 8819583a33fffff with 5
# searching for neighbor of 8819586087fffff
# found neighbors of 8819586087fffff with 14
# searching for neighbor of 8819586647fffff
# found neighbors of 8819586647fffff with 2
# searching for neighbor of 8819587469fffff
# found neighbors of 8819587469fffff with 4
# searching for neighbor of 881958745dfffff
# found neighbors of 881958745dfffff with 3
# searching for neighbor of 881958602bfffff
# found neighbors of 881958602bfffff with 17
# searching for neighbor of 88195839ddfffff
# found neighbors of 88195839ddfffff with 1
# searching for neighbor of 881958713dfffff
# found neighbors of 881958713dfffff with 19
# searching for neighbor of 881958600dfffff
# found neighbors of 881958600dfffff with 15
# searching for neighbor of 881958729bfffff
# found neighbors of 881958729bfffff with 6
# searching for neighbor of 8819582165fffff
# found neighbors of 8819582165fffff with 8
# searching for neighbor of 8819582acbfffff
# found neighbors of 8819582acbfffff with 6
# searching for neighbor of 8819582a57fffff
# found neighbors of 8819582a57fffff with 8
# searching for neighbor of 8819586ea1fffff
# found neighbors of 8819586ea1fffff with 23
# searching for neighbor of 88195829a9fffff
# found neighbors of 88195829a9fffff with 13
# searching for neighbor of 881958756dfffff
# found neighbors of 881958756dfffff with 2
# searching for neighbor of 8819580d89fffff
# found neighbors of 8819580d89fffff with 5
# searching for neighbor of 88195828e1fffff
# found neighbors of 88195828e1fffff with 5
# searching for neighbor of 88195874bdfffff
# found neighbors of 88195874bdfffff with 3
# searching for neighbor of 8819586013fffff
# found neighbors of 8819586013fffff with 14
# searching for neighbor of 8819587669fffff
# found neighbors of 8819587669fffff with 3
# searching for neighbor of 8819582aadfffff
# found neighbors of 8819582aadfffff with 2
# searching for neighbor of 881958711bfffff
# found neighbors of 881958711bfffff with 15
# searching for neighbor of 88195870c5fffff
# found neighbors of 88195870c5fffff with 7
# searching for neighbor of 8819580595fffff
# found neighbors of 8819580595fffff with 3
# searching for neighbor of 88195839a5fffff
# found neighbors of 88195839a5fffff with 0
# searching for neighbor of 88195872a1fffff
# found neighbors of 88195872a1fffff with 8
# searching for neighbor of 881958776dfffff
# found neighbors of 881958776dfffff with 4
# searching for neighbor of 8819582821fffff
# found neighbors of 8819582821fffff with 7
# searching for neighbor of 8819583955fffff
# found neighbors of 8819583955fffff with 1
# searching for neighbor of 881958620bfffff
# found neighbors of 881958620bfffff with 7
# searching for neighbor of 881958646dfffff
# found neighbors of 881958646dfffff with 7
# searching for neighbor of 8819586003fffff
# found neighbors of 8819586003fffff with 15
# searching for neighbor of 8819587183fffff
# found neighbors of 8819587183fffff with 11
# searching for neighbor of 8819586e63fffff
# found neighbors of 8819586e63fffff with 21
# searching for neighbor of 8819582841fffff
# found neighbors of 8819582841fffff with 7
# searching for neighbor of 8819580dc5fffff
# found neighbors of 8819580dc5fffff with 7
# searching for neighbor of 8819586369fffff
# found neighbors of 8819586369fffff with 15
# searching for neighbor of 881958745bfffff
# found neighbors of 881958745bfffff with 2
# searching for neighbor of 881958662dfffff
# found neighbors of 881958662dfffff with 2
# searching for neighbor of 8819586091fffff
# found neighbors of 8819586091fffff with 12
# searching for neighbor of 88195862e3fffff
# found neighbors of 88195862e3fffff with 9
# searching for neighbor of 8819586095fffff
# found neighbors of 8819586095fffff with 13
# searching for neighbor of 8819580ed7fffff
# found neighbors of 8819580ed7fffff with 4
# searching for neighbor of 8819587193fffff
# found neighbors of 8819587193fffff with 8
# searching for neighbor of 88195862b9fffff
# found neighbors of 88195862b9fffff with 11
# searching for neighbor of 88195866d7fffff
# found neighbors of 88195866d7fffff with 11
# searching for neighbor of 881958650dfffff
# found neighbors of 881958650dfffff with 13
# searching for neighbor of 8819586189fffff
# found neighbors of 8819586189fffff with 19
# searching for neighbor of 8819586e61fffff
# found neighbors of 8819586e61fffff with 21
# searching for neighbor of 88195874abfffff
# found neighbors of 88195874abfffff with 2
# searching for neighbor of 8819586663fffff
# found neighbors of 8819586663fffff with 0
# searching for neighbor of 8819586e31fffff
# found neighbors of 8819586e31fffff with 22
# searching for neighbor of 8819587511fffff
# found neighbors of 8819587511fffff with 2
# searching for neighbor of 88195865e1fffff
# found neighbors of 88195865e1fffff with 14
# searching for neighbor of 8819580de3fffff
# found neighbors of 8819580de3fffff with 7
# searching for neighbor of 8819580eb9fffff
# found neighbors of 8819580eb9fffff with 1
# searching for neighbor of 8819582933fffff
# found neighbors of 8819582933fffff with 10
# searching for neighbor of 8819580e9dfffff
# found neighbors of 8819580e9dfffff with 3
# searching for neighbor of 8819583849fffff
# found neighbors of 8819583849fffff with 2
# searching for neighbor of 8819582b6bfffff
# found neighbors of 8819582b6bfffff with 3
# searching for neighbor of 8819587637fffff
# found neighbors of 8819587637fffff with 3
# searching for neighbor of 8819586237fffff
# found neighbors of 8819586237fffff with 11
# searching for neighbor of 8819580dd5fffff
# found neighbors of 8819580dd5fffff with 4
# searching for neighbor of 8819582a21fffff
# found neighbors of 8819582a21fffff with 6
# searching for neighbor of 88195875cdfffff
# found neighbors of 88195875cdfffff with 2
# searching for neighbor of 8819582a1dfffff
# found neighbors of 8819582a1dfffff with 8
# searching for neighbor of 88195870ddfffff
# found neighbors of 88195870ddfffff with 5
# searching for neighbor of 8819587549fffff
# found neighbors of 8819587549fffff with 2
# searching for neighbor of 881958058dfffff
# found neighbors of 881958058dfffff with 4
# searching for neighbor of 8819582935fffff
# found neighbors of 8819582935fffff with 9
# searching for neighbor of 8819586507fffff
# found neighbors of 8819586507fffff with 14
# searching for neighbor of 881958213dfffff
# found neighbors of 881958213dfffff with 8
# searching for neighbor of 88195876edfffff
# found neighbors of 88195876edfffff with 1
# searching for neighbor of 88195805b3fffff
# found neighbors of 88195805b3fffff with 3
# searching for neighbor of 8819587731fffff
# found neighbors of 8819587731fffff with 2
# searching for neighbor of 8819582b11fffff
# found neighbors of 8819582b11fffff with 4
# searching for neighbor of 8819586551fffff
# found neighbors of 8819586551fffff with 10
# searching for neighbor of 8819582b3bfffff
# found neighbors of 8819582b3bfffff with 3
# searching for neighbor of 8819580591fffff
# found neighbors of 8819580591fffff with 2
# searching for neighbor of 881958752bfffff
# found neighbors of 881958752bfffff with 4
# searching for neighbor of 88195866d3fffff
# found neighbors of 88195866d3fffff with 12
# searching for neighbor of 8819586547fffff
# found neighbors of 8819586547fffff with 12
# searching for neighbor of 88195865c9fffff
# found neighbors of 88195865c9fffff with 11
# searching for neighbor of 8819583939fffff
# found neighbors of 8819583939fffff with 1
# searching for neighbor of 8819582b0bfffff
# found neighbors of 8819582b0bfffff with 3
# searching for neighbor of 8819586755fffff
# found neighbors of 8819586755fffff with 4
# searching for neighbor of 8819586ec1fffff
# found neighbors of 8819586ec1fffff with 18
# searching for neighbor of 8819587189fffff
# found neighbors of 8819587189fffff with 12
# searching for neighbor of 88195861d5fffff
# found neighbors of 88195861d5fffff with 18
# searching for neighbor of 8819583a35fffff
# found neighbors of 8819583a35fffff with 3
# searching for neighbor of 88195876c1fffff
# found neighbors of 88195876c1fffff with 1
# searching for neighbor of 8819582941fffff
# found neighbors of 8819582941fffff with 3
# searching for neighbor of 8819586423fffff
# found neighbors of 8819586423fffff with 10
# searching for neighbor of 8819587755fffff
# found neighbors of 8819587755fffff with 2
# searching for neighbor of 88195838e3fffff
# found neighbors of 88195838e3fffff with 3
# searching for neighbor of 88195871b1fffff
# found neighbors of 88195871b1fffff with 11
# searching for neighbor of 88195839bdfffff
# found neighbors of 88195839bdfffff with 3
# searching for neighbor of 8819582a63fffff
# found neighbors of 8819582a63fffff with 7
# searching for neighbor of 88195860c7fffff
# found neighbors of 88195860c7fffff with 13
# searching for neighbor of 88195860adfffff
# found neighbors of 88195860adfffff with 16
# searching for neighbor of 8819582a03fffff
# found neighbors of 8819582a03fffff with 8
# searching for neighbor of 88195860c5fffff
# found neighbors of 88195860c5fffff with 14
# searching for neighbor of 88195874d1fffff
# found neighbors of 88195874d1fffff with 4
# searching for neighbor of 8819586089fffff
# found neighbors of 8819586089fffff with 12
# searching for neighbor of 8819586267fffff
# found neighbors of 8819586267fffff with 10
# searching for neighbor of 8819586283fffff
# found neighbors of 8819586283fffff with 10
# searching for neighbor of 881958769bfffff
# found neighbors of 881958769bfffff with 1
# searching for neighbor of 8819582947fffff
# found neighbors of 8819582947fffff with 4
# searching for neighbor of 881958708bfffff
# found neighbors of 881958708bfffff with 4
# searching for neighbor of 8819586525fffff
# found neighbors of 8819586525fffff with 17
# searching for neighbor of 8819583901fffff
# found neighbors of 8819583901fffff with 0
# searching for neighbor of 8819582867fffff
# found neighbors of 8819582867fffff with 5
# searching for neighbor of 8819586729fffff
# found neighbors of 8819586729fffff with 8
# searching for neighbor of 8819582931fffff
# found neighbors of 8819582931fffff with 9
# searching for neighbor of 8819582913fffff
# found neighbors of 8819582913fffff with 9
# searching for neighbor of 8819582847fffff
# found neighbors of 8819582847fffff with 7
# searching for neighbor of 8819580ca3fffff
# found neighbors of 8819580ca3fffff with 2
# searching for neighbor of 881958212bfffff
# found neighbors of 881958212bfffff with 8
# searching for neighbor of 881958609dfffff
# found neighbors of 881958609dfffff with 12
# searching for neighbor of 8819583821fffff
# found neighbors of 8819583821fffff with 1
# searching for neighbor of 8819587293fffff
# found neighbors of 8819587293fffff with 5
# searching for neighbor of 8819580dbbfffff
# found neighbors of 8819580dbbfffff with 3
# searching for neighbor of 8819582ab5fffff
# found neighbors of 8819582ab5fffff with 1
# searching for neighbor of 8819582131fffff
# found neighbors of 8819582131fffff with 8
# searching for neighbor of 8819586533fffff
# found neighbors of 8819586533fffff with 15
# searching for neighbor of 8819586e8bfffff
# found neighbors of 8819586e8bfffff with 19
# searching for neighbor of 88195860d9fffff
# found neighbors of 88195860d9fffff with 10
# searching for neighbor of 88195876d1fffff
# found neighbors of 88195876d1fffff with 1
# searching for neighbor of 88195862e5fffff
# found neighbors of 88195862e5fffff with 10
# searching for neighbor of 8819586e1bfffff
# found neighbors of 8819586e1bfffff with 18
# searching for neighbor of 8819587537fffff
# found neighbors of 8819587537fffff with 6
# searching for neighbor of 8819580cc9fffff
# found neighbors of 8819580cc9fffff with 0
# searching for neighbor of 8819587053fffff
# found neighbors of 8819587053fffff with 10
# searching for neighbor of 8819587003fffff
# found neighbors of 8819587003fffff with 11
# searching for neighbor of 8819587683fffff
# found neighbors of 8819587683fffff with 2
# searching for neighbor of 8819583b51fffff
# found neighbors of 8819583b51fffff with 1
# searching for neighbor of 881958740dfffff
# found neighbors of 881958740dfffff with 4
# searching for neighbor of 881958654bfffff
# found neighbors of 881958654bfffff with 10
# searching for neighbor of 8819586667fffff
# found neighbors of 8819586667fffff with 1
# searching for neighbor of 8819586ea9fffff
# found neighbors of 8819586ea9fffff with 22
# searching for neighbor of 881958625dfffff
# found neighbors of 881958625dfffff with 5
# searching for neighbor of 8819587027fffff
# found neighbors of 8819587027fffff with 14
# searching for neighbor of 88195829d7fffff
# found neighbors of 88195829d7fffff with 9
# searching for neighbor of 88195862bbfffff
# found neighbors of 88195862bbfffff with 10
# searching for neighbor of 8819582865fffff
# found neighbors of 8819582865fffff with 4
# searching for neighbor of 8819583893fffff
# found neighbors of 8819583893fffff with 9
# searching for neighbor of 8819582aa5fffff
# found neighbors of 8819582aa5fffff with 2
# searching for neighbor of 8819583b01fffff
# found neighbors of 8819583b01fffff with 1
# searching for neighbor of 8819587629fffff
# found neighbors of 8819587629fffff with 2
# searching for neighbor of 8819583989fffff
# found neighbors of 8819583989fffff with 2
# searching for neighbor of 8819580cdbfffff
# found neighbors of 8819580cdbfffff with 0
# searching for neighbor of 88195839c1fffff
# found neighbors of 88195839c1fffff with 2
# searching for neighbor of 88195862e9fffff
# found neighbors of 88195862e9fffff with 8
# searching for neighbor of 88195838abfffff
# found neighbors of 88195838abfffff with 4
# searching for neighbor of 8819582849fffff
# found neighbors of 8819582849fffff with 7
# searching for neighbor of 8819580c11fffff
# found neighbors of 8819580c11fffff with 3
# searching for neighbor of 88195860bbfffff
# found neighbors of 88195860bbfffff with 14
# searching for neighbor of 881958759dfffff
# found neighbors of 881958759dfffff with 3
# searching for neighbor of 8819586ec9fffff
# found neighbors of 8819586ec9fffff with 17
# searching for neighbor of 881958600bfffff
# found neighbors of 881958600bfffff with 14
# searching for neighbor of 8819586513fffff
# found neighbors of 8819586513fffff with 12
# searching for neighbor of 8819587a99fffff
# found neighbors of 8819587a99fffff with 16
# searching for neighbor of 8819580eb3fffff
# found neighbors of 8819580eb3fffff with 2
# searching for neighbor of 8819587613fffff
# found neighbors of 8819587613fffff with 1
# searching for neighbor of 8819582a83fffff
# found neighbors of 8819582a83fffff with 3
# searching for neighbor of 8819586e49fffff
# found neighbors of 8819586e49fffff with 17
# searching for neighbor of 881958728dfffff
# found neighbors of 881958728dfffff with 9
# searching for neighbor of 8819587595fffff
# found neighbors of 8819587595fffff with 4
# searching for neighbor of 8819583b2bfffff
# found neighbors of 8819583b2bfffff with 1
# searching for neighbor of 8819586e41fffff
# found neighbors of 8819586e41fffff with 18
# searching for neighbor of 8819580cc1fffff
# found neighbors of 8819580cc1fffff with 0
# searching for neighbor of 88195838d7fffff
# found neighbors of 88195838d7fffff with 7
# searching for neighbor of 8819583917fffff
# found neighbors of 8819583917fffff with 1
# searching for neighbor of 8819582853fffff
# found neighbors of 8819582853fffff with 3
# searching for neighbor of 88195805bdfffff
# found neighbors of 88195805bdfffff with 5
# searching for neighbor of 88195871c3fffff
# found neighbors of 88195871c3fffff with 12
# searching for neighbor of 881958216bfffff
# found neighbors of 881958216bfffff with 10
# searching for neighbor of 8819580d8dfffff
# found neighbors of 8819580d8dfffff with 6
# searching for neighbor of 8819582b13fffff
# found neighbors of 8819582b13fffff with 5
# searching for neighbor of 8819586ed9fffff
# found neighbors of 8819586ed9fffff with 16
# searching for neighbor of 8819582905fffff
# found neighbors of 8819582905fffff with 6
# searching for neighbor of 88195861c3fffff
# found neighbors of 88195861c3fffff with 19
# searching for neighbor of 8819587703fffff
# found neighbors of 8819587703fffff with 2
# searching for neighbor of 88195862bdfffff
# found neighbors of 88195862bdfffff with 12
# searching for neighbor of 8819586655fffff
# found neighbors of 8819586655fffff with 3
# searching for neighbor of 881958675bfffff
# found neighbors of 881958675bfffff with 2
# searching for neighbor of 8819586201fffff
# found neighbors of 8819586201fffff with 8
# searching for neighbor of 8819580dbdfffff
# found neighbors of 8819580dbdfffff with 4
# searching for neighbor of 8819583985fffff
# found neighbors of 8819583985fffff with 2
# searching for neighbor of 8819582b21fffff
# found neighbors of 8819582b21fffff with 1
# searching for neighbor of 88195865c1fffff
# found neighbors of 88195865c1fffff with 12
# searching for neighbor of 881958748bfffff
# found neighbors of 881958748bfffff with 4
# searching for neighbor of 8819587529fffff
# found neighbors of 8819587529fffff with 3
# searching for neighbor of 8819583925fffff
# found neighbors of 8819583925fffff with 1
# searching for neighbor of 8819586621fffff
# found neighbors of 8819586621fffff with 2
# searching for neighbor of 88195828c1fffff
# found neighbors of 88195828c1fffff with 2
# searching for neighbor of 8819582951fffff
# found neighbors of 8819582951fffff with 5
# searching for neighbor of 88195874e7fffff
# found neighbors of 88195874e7fffff with 1
# searching for neighbor of 8819582985fffff
# found neighbors of 8819582985fffff with 12
# searching for neighbor of 8819586561fffff
# found neighbors of 8819586561fffff with 14
# searching for neighbor of 8819587137fffff
# found neighbors of 8819587137fffff with 18
# searching for neighbor of 8819583a6bfffff
# found neighbors of 8819583a6bfffff with 4
# searching for neighbor of 8819587131fffff
# found neighbors of 8819587131fffff with 18
# ...
# found neighbors of 881958774dfffff with 5
# searching for neighbor of 881958392bfffff
# found neighbors of 881958392bfffff with 0
# searching for neighbor of 8819580ea1fffff
# found neighbors of 8819580ea1fffff with 2
# searching for neighbor of 8819582a59fffff
# found neighbors of 8819582a59fffff with 7
# searching for neighbor of 88195876b9fffff
# found neighbors of 88195876b9fffff with 3
# searching for neighbor of 88195862cbfffff
# found neighbors of 88195862cbfffff with 7
# searching for neighbor of 88195862c3fffff
# found neighbors of 88195862c3fffff with 8
# searching for neighbor of 88195838e1fffff
# found neighbors of 88195838e1fffff with 2
# searching for neighbor of 8819587557fffff
# found neighbors of 8819587557fffff with 2
# searching for neighbor of 8819583961fffff
# found neighbors of 8819583961fffff with 0
# searching for neighbor of 88195860a9fffff
# found neighbors of 88195860a9fffff with 15
# searching for neighbor of 88195870d1fffff
# found neighbors of 88195870d1fffff with 4
# searching for neighbor of 881958615bfffff
# found neighbors of 881958615bfffff with 18
# searching for neighbor of 88195870b1fffff
# found neighbors of 88195870b1fffff with 4
# searching for neighbor of 8819582857fffff
# found neighbors of 8819582857fffff with 4
# searching for neighbor of 8819587483fffff
# found neighbors of 8819587483fffff with 4
# searching for neighbor of 8819583a03fffff
# found neighbors of 8819583a03fffff with 5
# searching for neighbor of 8819580cc3fffff
# found neighbors of 8819580cc3fffff with 1
# searching for neighbor of 8819587517fffff
# found neighbors of 8819587517fffff with 3
# searching for neighbor of 8819586057fffff
# found neighbors of 8819586057fffff with 13
# searching for neighbor of 8819587685fffff
# found neighbors of 8819587685fffff with 1
# searching for neighbor of 88195870edfffff
# found neighbors of 88195870edfffff with 9
# searching for neighbor of 8819587711fffff
# found neighbors of 8819587711fffff with 3
# searching for neighbor of 88195829e9fffff
# found neighbors of 88195829e9fffff with 10
# searching for neighbor of 8819587ad3fffff
# found neighbors of 8819587ad3fffff with 16
# searching for neighbor of 88195861cbfffff
# found neighbors of 88195861cbfffff with 19
# searching for neighbor of 8819586221fffff
# found neighbors of 8819586221fffff with 11
# searching for neighbor of 8819583b17fffff
# found neighbors of 8819583b17fffff with 1
# searching for neighbor of 8819583991fffff
# found neighbors of 8819583991fffff with 3
# searching for neighbor of 88195875c1fffff
# found neighbors of 88195875c1fffff with 3
# searching for neighbor of 88195839b1fffff
# found neighbors of 88195839b1fffff with 4
# searching for neighbor of 8819583865fffff
# found neighbors of 8819583865fffff with 1
# searching for neighbor of 881958718dfffff
# found neighbors of 881958718dfffff with 13
# searching for neighbor of 88195875bbfffff
# found neighbors of 88195875bbfffff with 3
# searching for neighbor of 8819582a97fffff
# found neighbors of 8819582a97fffff with 4
# searching for neighbor of 88195839e7fffff
# found neighbors of 88195839e7fffff with 2
# searching for neighbor of 8819583a37fffff
# found neighbors of 8819583a37fffff with 4
# searching for neighbor of 8819587607fffff
# found neighbors of 8819587607fffff with 3
# searching for neighbor of 8819587727fffff
# found neighbors of 8819587727fffff with 2
# searching for neighbor of 88195875adfffff
# found neighbors of 88195875adfffff with 6
# searching for neighbor of 8819583957fffff
# found neighbors of 8819583957fffff with 1
# searching for neighbor of 8819582937fffff
# found neighbors of 8819582937fffff with 10
# searching for neighbor of 8819586305fffff
# found neighbors of 8819586305fffff with 16
# searching for neighbor of 8819582ad5fffff
# found neighbors of 8819582ad5fffff with 5
# searching for neighbor of 8819587485fffff
# found neighbors of 8819587485fffff with 2
# searching for neighbor of 881958655dfffff
# found neighbors of 881958655dfffff with 10
# searching for neighbor of 8819583967fffff
# found neighbors of 8819583967fffff with 1
# searching for neighbor of 88195838e7fffff
# found neighbors of 88195838e7fffff with 2
# searching for neighbor of 881958608bfffff
# found neighbors of 881958608bfffff with 12
# searching for neighbor of 8819587623fffff
# found neighbors of 8819587623fffff with 3
# searching for neighbor of 88195874b7fffff
# found neighbors of 88195874b7fffff with 4
# searching for neighbor of 8819587297fffff
# found neighbors of 8819587297fffff with 5
# searching for neighbor of 88195829a1fffff
# found neighbors of 88195829a1fffff with 14
# searching for neighbor of 8819583969fffff
# found neighbors of 8819583969fffff with 1
# searching for neighbor of 8819582929fffff
# found neighbors of 8819582929fffff with 7
# searching for neighbor of 8819582b07fffff
# found neighbors of 8819582b07fffff with 1
# searching for neighbor of 881958388dfffff
# found neighbors of 881958388dfffff with 4
# searching for neighbor of 8819583b0dfffff
# found neighbors of 8819583b0dfffff with 2
# searching for neighbor of 88195866a7fffff
# found neighbors of 88195866a7fffff with 10
# searching for neighbor of 88195805abfffff
# found neighbors of 88195805abfffff with 5
# searching for neighbor of 8819586319fffff
# found neighbors of 8819586319fffff with 13
# searching for neighbor of 8819582a9bfffff
# found neighbors of 8819582a9bfffff with 5
# searching for neighbor of 8819587187fffff
# found neighbors of 8819587187fffff with 12
# searching for neighbor of 8819587699fffff
# found neighbors of 8819587699fffff with 0
# searching for neighbor of 8819582963fffff
# found neighbors of 8819582963fffff with 6
# searching for neighbor of 8819586449fffff
# found neighbors of 8819586449fffff with 4
# searching for neighbor of 8819582f4dfffff
# found neighbors of 8819582f4dfffff with 6
# searching for neighbor of 8819580cabfffff
# found neighbors of 8819580cabfffff with 1
# searching for neighbor of 8819582133fffff
# found neighbors of 8819582133fffff with 8
# searching for neighbor of 8819586e03fffff
# found neighbors of 8819586e03fffff with 20
# searching for neighbor of 881958758bfffff
# found neighbors of 881958758bfffff with 3
# searching for neighbor of 88195872d3fffff
# found neighbors of 88195872d3fffff with 7
# searching for neighbor of 881958634bfffff
# found neighbors of 881958634bfffff with 12
# searching for neighbor of 8819583b07fffff
# found neighbors of 8819583b07fffff with 0
# searching for neighbor of 88195860e3fffff
# found neighbors of 88195860e3fffff with 14
# searching for neighbor of 8819583b53fffff
# found neighbors of 8819583b53fffff with 0
# searching for neighbor of 8819586515fffff
# found neighbors of 8819586515fffff with 13
# searching for neighbor of 88195839abfffff
# found neighbors of 88195839abfffff with 2
# searching for neighbor of 8819583855fffff
# found neighbors of 8819583855fffff with 4
# searching for neighbor of 8819580cb7fffff
# found neighbors of 8819580cb7fffff with 2
# searching for neighbor of 8819586265fffff
# found neighbors of 8819586265fffff with 10
# searching for neighbor of 8819580ce5fffff
# found neighbors of 8819580ce5fffff with 2
# searching for neighbor of 88195871ebfffff
# found neighbors of 88195871ebfffff with 14
# searching for neighbor of 8819586511fffff
# found neighbors of 8819586511fffff with 12
# searching for neighbor of 8819587653fffff
# found neighbors of 8819587653fffff with 0
# searching for neighbor of 8819587741fffff
# found neighbors of 8819587741fffff with 4
# searching for neighbor of 8819587655fffff
# found neighbors of 8819587655fffff with 1
# searching for neighbor of 8819587415fffff
# found neighbors of 8819587415fffff with 5
# searching for neighbor of 8819587619fffff
# found neighbors of 8819587619fffff with 0
# searching for neighbor of 88195871bdfffff
# found neighbors of 88195871bdfffff with 12
# searching for neighbor of 8819582137fffff
# found neighbors of 8819582137fffff with 7
# searching for neighbor of 88195805a9fffff
# found neighbors of 88195805a9fffff with 5
# searching for neighbor of 88195874e3fffff
# found neighbors of 88195874e3fffff with 2
# searching for neighbor of 8819586739fffff
# found neighbors of 8819586739fffff with 7
# searching for neighbor of 881958296dfffff
# found neighbors of 881958296dfffff with 6
# searching for neighbor of 8819582981fffff
# found neighbors of 8819582981fffff with 11
# searching for neighbor of 8819586653fffff
# found neighbors of 8819586653fffff with 5
# searching for neighbor of 8819586703fffff
# found neighbors of 8819586703fffff with 6
# searching for neighbor of 881958618bfffff
# found neighbors of 881958618bfffff with 19
# searching for neighbor of 8819587757fffff
# found neighbors of 8819587757fffff with 2
# searching for neighbor of 8819583aa7fffff
# found neighbors of 8819583aa7fffff with 6
# searching for neighbor of 8819587725fffff
# found neighbors of 8819587725fffff with 2
# searching for neighbor of 881958753bfffff
# found neighbors of 881958753bfffff with 4
# searching for neighbor of 8819582f69fffff
# found neighbors of 8819582f69fffff with 5
# searching for neighbor of 88195870d5fffff
# found neighbors of 88195870d5fffff with 5
# searching for neighbor of 88195871d7fffff
# found neighbors of 88195871d7fffff with 10
# searching for neighbor of 881958395bfffff
# found neighbors of 881958395bfffff with 1
# searching for neighbor of 8819582a13fffff
# found neighbors of 8819582a13fffff with 6
# searching for neighbor of 8819587a9bfffff
# found neighbors of 8819587a9bfffff with 15
# searching for neighbor of 8819582813fffff
# found neighbors of 8819582813fffff with 3
# searching for neighbor of 8819583b55fffff
# found neighbors of 8819583b55fffff with 1
# searching for neighbor of 8819586405fffff
# found neighbors of 8819586405fffff with 8
# searching for neighbor of 8819586759fffff
# found neighbors of 8819586759fffff with 3
# searching for neighbor of 8819583a61fffff
# found neighbors of 8819583a61fffff with 3
# searching for neighbor of 881958629bfffff
# found neighbors of 881958629bfffff with 8
# searching for neighbor of 88195870cbfffff
# found neighbors of 88195870cbfffff with 6
# searching for neighbor of 88195875e3fffff
# found neighbors of 88195875e3fffff with 5
# searching for neighbor of 8819580db9fffff
# found neighbors of 8819580db9fffff with 4
# searching for neighbor of 8819587581fffff
# found neighbors of 8819587581fffff with 4
# searching for neighbor of 8819583a65fffff
# found neighbors of 8819583a65fffff with 2
# searching for neighbor of 8819583997fffff
# found neighbors of 8819583997fffff with 4
# searching for neighbor of 8819580dcbfffff
# found neighbors of 8819580dcbfffff with 5
# searching for neighbor of 8819586019fffff
# found neighbors of 8819586019fffff with 13
# searching for neighbor of 8819582a25fffff
# found neighbors of 8819582a25fffff with 5
# searching for neighbor of 8819587295fffff
# found neighbors of 8819587295fffff with 6
# searching for neighbor of 8819582b17fffff
# found neighbors of 8819582b17fffff with 4
# searching for neighbor of 8819582837fffff
# found neighbors of 8819582837fffff with 7
# searching for neighbor of 881958059bfffff
# found neighbors of 881958059bfffff with 2
# searching for neighbor of 88195870c1fffff
# found neighbors of 88195870c1fffff with 7
# searching for neighbor of 881958601dfffff
# found neighbors of 881958601dfffff with 14
# searching for neighbor of 8819582ae3fffff
# found neighbors of 8819582ae3fffff with 3
# searching for neighbor of 881958719bfffff
# found neighbors of 881958719bfffff with 8
# searching for neighbor of 88195838cdfffff
# found neighbors of 88195838cdfffff with 5
# searching for neighbor of 88195861ddfffff
# found neighbors of 88195861ddfffff with 18
# searching for neighbor of 8819587513fffff
# found neighbors of 8819587513fffff with 2
# searching for neighbor of 8819586645fffff
# found neighbors of 8819586645fffff with 2
# searching for neighbor of 88195862d9fffff
# found neighbors of 88195862d9fffff with 6
# searching for neighbor of 8819586ec3fffff
# found neighbors of 8819586ec3fffff with 18
# searching for neighbor of 8819587717fffff
# found neighbors of 8819587717fffff with 4
# searching for neighbor of 881958670dfffff
# found neighbors of 881958670dfffff with 6
# searching for neighbor of 8819586607fffff
# found neighbors of 8819586607fffff with 2
# searching for neighbor of 88195865edfffff
# found neighbors of 88195865edfffff with 14
# searching for neighbor of 8819587195fffff
# found neighbors of 8819587195fffff with 10
# searching for neighbor of 88195866b9fffff
# found neighbors of 88195866b9fffff with 10
# searching for neighbor of 8819580debfffff
# found neighbors of 8819580debfffff with 7
# searching for neighbor of 88195871dbfffff
# found neighbors of 88195871dbfffff with 9
# searching for neighbor of 88195862b1fffff
# found neighbors of 88195862b1fffff with 11
# searching for neighbor of 881958636bfffff
# found neighbors of 881958636bfffff with 15
# searching for neighbor of 8819583b41fffff
# found neighbors of 8819583b41fffff with 3
# searching for neighbor of 88195872d1fffff
# found neighbors of 88195872d1fffff with 8
# searching for neighbor of 8819583859fffff
# found neighbors of 8819583859fffff with 5
# searching for neighbor of 88195829c9fffff
# found neighbors of 88195829c9fffff with 8
# searching for neighbor of 88195871e3fffff
# found neighbors of 88195871e3fffff with 14
# searching for neighbor of 8819580da9fffff
# found neighbors of 8819580da9fffff with 6
# searching for neighbor of 8819583a27fffff
# found neighbors of 8819583a27fffff with 2
# searching for neighbor of 8819586253fffff
# found neighbors of 8819586253fffff with 5
# searching for neighbor of 88195870c3fffff
# found neighbors of 88195870c3fffff with 6
# searching for neighbor of 8819586191fffff
# found neighbors of 8819586191fffff with 19
# searching for neighbor of 8819582b1dfffff
# found neighbors of 8819582b1dfffff with 3
# searching for neighbor of 88195860abfffff
# found neighbors of 88195860abfffff with 15
# searching for neighbor of 8819582b61fffff
# found neighbors of 8819582b61fffff with 3
# searching for neighbor of 881958386dfffff
# found neighbors of 881958386dfffff with 1
# searching for neighbor of 8819587647fffff
# found neighbors of 8819587647fffff with 3
# searching for neighbor of 8819582a91fffff
# found neighbors of 8819582a91fffff with 4
# searching for neighbor of 8819582a5dfffff
# found neighbors of 8819582a5dfffff with 6
# searching for neighbor of 8819586531fffff
# found neighbors of 8819586531fffff with 15
# searching for neighbor of 8819586203fffff
# found neighbors of 8819586203fffff with 8
# searching for neighbor of 8819582aebfffff
# found neighbors of 8819582aebfffff with 4
# searching for neighbor of 8819583b4dfffff
# found neighbors of 8819583b4dfffff with 4
# searching for neighbor of 8819587181fffff
# found neighbors of 8819587181fffff with 12
# searching for neighbor of 88195871e7fffff
# found neighbors of 88195871e7fffff with 15
# searching for neighbor of 8819583895fffff
# found neighbors of 8819583895fffff with 7
# searching for neighbor of 88195871b5fffff
# found neighbors of 88195871b5fffff with 12
# searching for neighbor of 881958283dfffff
# found neighbors of 881958283dfffff with 6
# searching for neighbor of 88195805d3fffff
# found neighbors of 88195805d3fffff with 0
# searching for neighbor of 8819580de1fffff
# found neighbors of 8819580de1fffff with 8
# searching for neighbor of 88195805a3fffff
# found neighbors of 88195805a3fffff with 5
# searching for neighbor of 8819582a1bfffff
# found neighbors of 8819582a1bfffff with 7
# searching for neighbor of 88195860e9fffff
# found neighbors of 88195860e9fffff with 15
# searching for neighbor of 881958290bfffff
# found neighbors of 881958290bfffff with 6
# searching for neighbor of 8819586643fffff
# found neighbors of 8819586643fffff with 3
# searching for neighbor of 8819587435fffff
# found neighbors of 8819587435fffff with 3
# searching for neighbor of 88195866c1fffff
# found neighbors of 88195866c1fffff with 8
# searching for neighbor of 881958394bfffff
# found neighbors of 881958394bfffff with 1
# searching for neighbor of 8819587659fffff
# found neighbors of 8819587659fffff with 1
# searching for neighbor of 8819583b43fffff
# found neighbors of 8819583b43fffff with 2
# searching for neighbor of 8819583aa1fffff
# found neighbors of 8819583aa1fffff with 6
# searching for neighbor of 8819586357fffff
# found neighbors of 8819586357fffff with 13
# searching for neighbor of 88195860a7fffff
# found neighbors of 88195860a7fffff with 17
# searching for neighbor of 8819582815fffff
# found neighbors of 8819582815fffff with 4

# %% [markdown]
# ## Calculate Daily Simulation Parameter

# %%
simday = '2022-03-28 00:00:00'
env = simpy.Environment()
tmp_traffic_allocation = dpr.extract_traffic_data_by_date(simday, traffic_count_data=traffic_analysis_data)
tmp_traffic = traffic_analysis_data.query('CountDate == @simday').copy().reset_index()
tmp_station = station_analysis_data.query('Date == @simday').copy().reset_index()
avg_day_traffic = tmp_traffic['AllMotorVehicles'].mean()
daily_user = int(cfg.user_per_day* (ult.sig((avg_day_traffic/avg_2022_traffic)-1)+1))
# daily_user = int(cfg.user_per_day* (avg_day_traffic/avg_2022_traffic))
sim_car_list = sim.generate_car_list(daily_user, tmp_station)
sim_station_list = sim.generate_staion(env, tmp_station)
log_df = pd.DataFrame(columns=['timestamp', 'car_id', 'station_id', 'event_name'])

# %%
daily_user
# Out:
# 752

# %%
sim_result = pd.DataFrame()
# now = datetime.combine(datetime.now().date() + timedelta(days=1), 
#                        datetime.min.time())
# check_list = list(date_list[0:2])
for simday in date_list:
# for simday in check_list:
    sim_date = datetime.strptime(simday, '%Y-%m-%d %H:%M:%S')
    env = simpy.Environment()
    tmp_traffic_allocation = dpr.extract_traffic_data_by_date(simday, traffic_count_data=traffic_analysis_data)
    tmp_traffic = traffic_analysis_data.query('CountDate == @simday').copy().reset_index()
    tmp_station = station_analysis_data.query('Date == @simday').copy().reset_index()
    avg_day_traffic = tmp_traffic['AllMotorVehicles'].mean()
    daily_user = int(cfg.user_per_day*(ult.sig((avg_day_traffic/avg_2022_traffic)-1)+1))
    # daily_user = int(cfg.user_per_day* (avg_day_traffic/avg_2022_traffic))
    sim_car_list = sim.generate_car_list(daily_user, tmp_station)
    sim_station_list = sim.generate_staion(env, tmp_station)
    log_df = pd.DataFrame(columns=['timestamp', 'car_id', 'station_id', 'event_name', 'elapsed_time'])
    for id, ev in sim_car_list.iterrows():
        chosen_station = ev['ChargeDeviceId']
        station_info = dict(sim_station_list[sim_station_list['ChargeDeviceId'] == chosen_station].head(1))
        charge_time = ev['ChargeTime']
        car_id = ev['CarId']
        resource = station_info['Station'].values[0]
        env.process(sim.car(env,car_id,chosen_station,resource,charge_time,sim_date,log_df,traffic_allocation=tmp_traffic_allocation))
    env.run()
    log_df['date'] = simday
    sim_result = pd.concat([sim_result, log_df])
sim_result.to_csv('simulation/output/simulation_all_2022.csv', index=False)

# Runtime: 30s
# 45k rows

# %% [markdown]
# ## Analysis

# %% [markdown]
# There are 4 possible status for cars interacting with the stations:
#
# - 'arrive - charge': Arrive and charge right away
#
# - 'arrive - queue': Arrive but have to take a queue
#
# - 'charge - finish': Finish charging and leave
#
# - 'queue - charge': Queue then find a spot and start charging
#
# - 'queue - give up': Queue too long and have to give up
#
# Decided to use R for simpler visualizations.

# %%
sim_result = pd.read_csv('simulation/output/simulation_all_2022.csv')

# %%
sim_result.head(100)
# Out:
#               timestamp   car_id                        station_id  \
# 0   2022-03-21 02:18:40  bes0397  63ba327b26344b5f629861defddc2099
# 1   2022-03-21 02:41:14  bes0397  63ba327b26344b5f629861defddc2099
# 2   2022-03-21 02:56:38  bes0272  a39256a0972490978df0b4d85c5736be
# 3   2022-03-21 03:30:53  bes0088  6cc14668d720ff3088c3e2325745080c
# 4   2022-03-21 03:35:07  bes0123  90d60beb748605ceebd6f17551dd5a1d
# ..                  ...      ...                               ...
# 95  2022-03-21 08:09:42  bes0131  e757852199c96e39152d28c1efea00c0
# 96  2022-03-21 08:11:06  bes0361  1b7f860f0874f582a9118ec56a879e56
# 97  2022-03-21 08:12:15  bes0329  90d60beb748605ceebd6f17551dd5a1d
# 98  2022-03-21 08:13:11  bes0336  d30cca09053fc7dffbf5576cde094c45
# 99  2022-03-21 08:17:51  bes0058  ea2a6f3bb6028ac150aaed0ded9023ab
#
#          event_name                 date
# 0   arrive - charge  2022-03-21 00:00:00
# 1   charge - finish  2022-03-21 00:00:00
# 2   arrive - charge  2022-03-21 00:00:00
# 3   arrive - charge  2022-03-21 00:00:00
# 4   arrive - charge  2022-03-21 00:00:00
# ..              ...                  ...
# 95  arrive - charge  2022-03-21 00:00:00
# 96  charge - finish  2022-03-21 00:00:00
# 97  arrive - charge  2022-03-21 00:00:00
# 98  arrive - charge  2022-03-21 00:00:00
# 99  charge - finish  2022-03-21 00:00:00
#
# [100 rows x 5 columns]

# %%
np.unique(sim_result['event_name'])
# Out:
# array(['arrive - charge', 'arrive - queue', 'charge - finish',
#        'queue - charge', 'queue - give up'], dtype=object)

# %%
count_table = (sim_result.groupby(['date'], as_index=False)
               .agg(
                   count_car_demand = ('car_id', 'nunique'),
                   count_statio_used = ('station_id', 'nunique'),
                   count_queue_car = ('event')
                   ))
count_table
# Out:
#                    date  count_car  count_station
# 0   2022-03-21 00:00:00        503            109
# 1   2022-03-25 00:00:00        196             87
# 2   2022-03-28 00:00:00       1232            115
# 3   2022-03-29 00:00:00       1237            115
# 4   2022-04-08 00:00:00       1651            113
# 5   2022-04-27 00:00:00        215             93
# 6   2022-04-29 00:00:00        659            111
# 7   2022-05-05 00:00:00        741            110
# 8   2022-05-06 00:00:00       2031            114
# 9   2022-05-09 00:00:00       1392            115
# 10  2022-05-10 00:00:00        721            112
# 11  2022-05-12 00:00:00        337            101
# 12  2022-05-13 00:00:00        219             89
# 13  2022-05-16 00:00:00         20             18
# 14  2022-05-18 00:00:00        445            107
# 15  2022-05-23 00:00:00          4              4
# 16  2022-05-24 00:00:00       1948            116
# 17  2022-05-25 00:00:00        317            103
# 18  2022-05-26 00:00:00        537            112
# 19  2022-05-27 00:00:00         64             47
# 20  2022-06-08 00:00:00         13             12
# 21  2022-06-13 00:00:00         29             26
# 22  2022-06-14 00:00:00         87             57
# 23  2022-06-15 00:00:00        843            111
# 24  2022-06-16 00:00:00        311            104
# 25  2022-06-17 00:00:00         23             23
# 26  2022-06-20 00:00:00        343            107
# 27  2022-06-21 00:00:00          7              7
# 28  2022-06-28 00:00:00        128             71
# 29  2022-07-01 00:00:00          8              8
# 30  2022-07-05 00:00:00        378            107
# 31  2022-07-06 00:00:00         88             61
# 32  2022-07-07 00:00:00         57             48
# 33  2022-07-12 00:00:00        493            107
# 34  2022-07-13 00:00:00        152             84
# 35  2022-07-14 00:00:00        730            115
# 36  2022-09-06 00:00:00        234            103
# 37  2022-09-07 00:00:00        548            111
# 38  2022-09-13 00:00:00        119             70
# 39  2022-09-15 00:00:00        127             71
# 40  2022-09-16 00:00:00          6              6
# 41  2022-09-21 00:00:00         37             27
# 42  2022-09-23 00:00:00         21             21
# 43  2022-09-28 00:00:00         23             23
# 44  2022-09-29 00:00:00         56             44
# 45  2022-09-30 00:00:00         85             55
# 46  2022-10-04 00:00:00        578            115
# 47  2022-10-12 00:00:00        168             85
# 48  2022-10-13 00:00:00         30             26
# 49  2022-10-19 00:00:00        801            112
