# %%
from library.simulation_class import *
import json
import numpy as np
import pandas as pd
import pyrosm

# %%
with open('sys_files/user_data_all_rows.json') as file:
    vehicle_data = json.loads(file.read())

vehicle_data
# Out:
# [{'home': {'Latitude': 51.454404, 'Longitude': -2.593529},
#   'car': {'Latitude': 51.472674,
#    'Longitude': -2.6129294,
#    'connector2Type': '3-pin Type G (BS1363)'}},
#  {'home': {'Latitude': 51.459952, 'Longitude': -2.593543},
#   'car': {'Latitude': 51.486771006,
#    'Longitude': -2.518669261,
#    'connector2Type': 'CCS Type 2 Combo (IEC62196)'}},
#  {'home': {'Latitude': 51.464393, 'Longitude': -2.581192},
#   'car': {'Latitude': 51.408224496,
#    'Longitude': -2.726051917,
#    'connector2Type': 'CCS Type 2 Combo (IEC62196)'}},
#  {'home': {'Latitude': 51.452335, 'Longitude': -2.577427},
#   'car': {'Latitude': 51.427202607,
#    'Longitude': -2.650077159,
#    'connector2Type': 'Type 2 Mennekes (IEC62196)'}},
#  {'home': {'Latitude': 51.499183, 'Longitude': -2.66031},
#   'car': {'Latitude': 51.483331105,
#    'Longitude': -2.519825502,
#    'connector2Type': 'JEVS G105 (CHAdeMO) DC'}},
#  {'home': {'Latitude': 51.458457, 'Longitude': -2.574165},
# ...

# %%
vehicle_list = []

for i in range(0, len(vehicle_data)):
    vehicle_list.append(Vehicle(vehicle_data[0]['car']['Longitude'],
                                vehicle_data[0]['car']['Latitude'],
                                vehicle_data[0]['home']['Longitude'],
                                vehicle_data[0]['home']['Latitude'],
                                vehicle_data[0]['car']['connector2Type']))

# %%
vehicle_list[1].last_known_loc
# Out:
# [[datetime.datetime(2024, 3, 11, 15, 27, 29, 476491, tzinfo=datetime.timezone.utc),
#   -2.6129294,
#   51.472674]]
