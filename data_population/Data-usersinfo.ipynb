# %%
# !pip install string module
# Out:
# ERROR: Could not find a version that satisfies the requirement string (from versions: none)
# ERROR: No matching distribution found for string

# %% [markdown]
# # Cerating Json

# %%
import random
import pandas as pd
from faker import Faker
import json

fake = Faker()

# Load postcodes from the CSV file
postcodes_df = pd.read_csv("BS postcodes.csv")

# Original data
original_data = {
    "users": [
        {
            "name": "Fari",
            "age": 25,
            "email": "Fari@example.com",
            "phone": "0447756896541",
            "home_postcode": "BS1 1AA",
            "work_postcode": "BS2 2BB",
            "cars": [
                {
                    "registration_number": "AB12 CDE",
                    "model": "Ford Fiesta",
                    "year_of_registration": 2019,
                    "tax_due_date": "2024-03-31",
                    "mot_due_date": "2024-04-30",
                    "connector_type": "Type 2",
                    "active": True,
                    "last_session_id": "123456"
                },
                {
                    "registration_number": "FG34 HIJ",
                    "model": "Tesla Model 3",
                    "year_of_registration": 2021,
                    "tax_due_date": "2024-06-30",
                    "mot_due_date": "2024-07-31",
                    "connector_type": "CCS",
                    "last_session_id": "125656",
                    "active": False,
                },
            ]
        },
        {
            "name": "John",
            "age": 32,
            "email": "John@example.com",
            "phone": "0449876543121",
            "home_postcode": "BS3 3CC",
            "work_postcode": "BS4 4DD",
            "registration_date": "2023-05-30",
            "cars": [
                {
                    "registration_number": "KL56 MNO",
                    "model": "Nissan Leaf",
                    "year_of_registration": 2018,
                    "tax_due_date": "2024-05-31",
                    "mot_due_date": "2024-06-30",
                    "connector_type": "CHAdeMO",
                    "active": True,
                    "last_session_id": "128856"
                }
            ]
        }
    ]
}

# Simulate additional data for 500 records
for _ in range(500 - len(original_data["users"])):
    num_cars = random.randint(1, 3)
    cars = []

    for _ in range(num_cars):
        car = {
            "registration_number": ''.join(random.choice(string.ascii_uppercase) for _ in range(2)) + str(fake.random_int(10, 99)) + " " +
                                  ''.join(random.choice(string.ascii_uppercase) for _ in range(3)),
            "model": fake.word(),
            "year_of_registration": fake.random_int(2000, 2023),
            "tax_due_date": fake.date_between(start_date='today', end_date='+1y').strftime("%Y-%m-%d"),
            "mot_due_date": fake.date_between(start_date='today', end_date='+1y').strftime("%Y-%m-%d"),
            "connector_type": random.choice(["Type 2", "CCS", "CHAdeMO"]),
            "active": False,
            "last_session_id": fake.random_int(120000, 129999)
        }
        cars.append(car)

    # Ensure that only one car is active
    if cars:
        cars[random.randint(0, len(cars) - 1)]["active"] = True

    # Randomly choose home and work postcodes from the CSV file
    home_postcode = random.choice(postcodes_df["Postcode"])
    work_postcode = random.choice(postcodes_df["Postcode"])

    user_data = {
        "name": fake.first_name(),
        "age": random.randint(18, 60),
        "email": fake.email(),
        "phone": "0447" + str(fake.random_int(100000000, 199999999)),
        "home_postcode": home_postcode,
        "work_postcode": work_postcode,
        "cars": cars
    }
    original_data["users"].append(user_data)

# Save the simulated data to a new JSON file
with open("simulated_data.json", "w") as f:
    f.write(json.dumps(original_data, indent=2))

# %%
import random
import pandas as pd
from faker import Faker
import json
import string

fake = Faker()

# Load postcodes from the CSV file
postcodes_df = pd.read_csv("BS postcodes.csv")

# Load car data from the "cars.json" file
with open("cars.json", "r") as cars_file:
    cars_data = json.load(cars_file)["electric_cars"]

# Original data
original_data = {
    "users": [
        {
            "name": "Fari",
            "age": 25,
            "email": "Fari@example.com",
            "phone": "0447756896541",
            "home_postcode": "BS1 1AA",
            "work_postcode": "BS2 2BB",
            "cars": random.sample(cars_data, 1),
            "session_Id": fake.random_number(digits=10)
        },
        {
            "name": "John",
            "age": 32,
            "email": "John@example.com",
            "phone": "0449876543121",
            "home_postcode": "BS3 3CC",
            "work_postcode": "BS4 4DD",
            "cars": random.sample(cars_data, random.randint(1, 3)),
            "session_Id": fake.random_number(digits=10)
        }
    ]
}

#mongodb
mongodb_data= []
# Simulate data for 500 records
for _ in range(500 - len(original_data["users"])):
    num_cars = random.randint(1, 3)
    cars = random.sample(cars_data, num_cars)

    # Ensure that only one car is active
#     if len(cars) > 1:
    active_id = random.randint(1, len(cars)) - 1
    for i in range(0, len(cars)):
        if i == active_id:
            cars[i]["active"] = True
        else:
            cars[i]["active"] = False

#         active_car = random.choice(cars)
#         active_car["active"] = True
#         for car in cars:
#             if car != active_car:
#                 car["active"] = False
#     elif len(cars) == 1:
#         cars[0]["active"] = True

    # Randomly choose home and work postcodes from the CSV file
    home_postcode = random.choice(postcodes_df["Postcode"])
    work_postcode = random.choice(postcodes_df["Postcode"])

    user_data = {
        "name": fake.first_name(),
        "age": random.randint(18, 60),
        "email": fake.email(),
        "phone": "0447" + str(fake.random_int(100000000, 199999999)),
        "home_postcode": home_postcode,
        "work_postcode": work_postcode,
        "cars": cars,
        "session_Id": fake.random_number(digits=10)
    }
    mongodb_data.append(user_data)
    
    
    
 #   original_data["users"].append(user_data)

# Save the simulated data to a new JSON file
#with open("simulated_data.json", "w") as f:
 #   f.write(json.dumps(original_data, indent=2))

# %%
mongodb_data
# Out:
# [{'name': 'Sharon',
#   'age': 27,
#   'email': 'diane92@example.com',
#   'phone': '0447111385036',
#   'home_postcode': 'BS10 6EG',
#   'work_postcode': 'BS20 8DT',
#   'cars': [{'car': 'Tesla',
#     'model': 'Model Y',
#     'charger_type': 'Type 2 (Tesla Supercharger)',
#     'active': False}],
#   'session_Id': 3112974125},
#  {'name': 'Carrie',
#   'age': 19,
#   'email': 'michelle85@example.net',
#   'phone': '0447179223159',
#   'home_postcode': 'BS16 6DB',
#   'work_postcode': 'BS1 2BN',
#   'cars': [{'car': 'BMW',
#     'model': 'iX3',
#     'charger_type': 'CCS Combo',
#     'active': True},
#    {'car': 'Tesla',
#     'model': 'Model 3 Performance',
#     'charger_type': 'Type 2 (Tesla Supercharger)',
#     'active': False}],
#   'session_Id': 6235097715},
#  {'name': 'Alicia',
#   'age': 56,
#   'email': 'jennifer89@example.org',
#   'phone': '0447121126544',
#   'home_postcode': 'BS23 4AB',
#   'work_postcode': 'BS34 5TN',
#   'cars': [{'car': 'Citroen',
# ...

# %% [markdown]
# # To Mangodb

# %%
import pymongo
from pymongo import InsertOne
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# %%
uri = "mongodb+srv://farinaz334:Fari15733@cluster0.aaqqg7h.mongodb.net"
client = MongoClient(uri)

try:
    client.admin.command("ping")
    print("ok")
except Exception as e:
    print (e)

db = client.igp_group_7_data
collection = db.user_info
# Out:
# ok

# %%
collection.insert_many(mongodb_data)
# Out:
# InsertManyResult([ObjectId('65d768b1c852a99dc223101b'), ObjectId('65d768b1c852a99dc223101c'), ObjectId('65d768b1c852a99dc223101d'), ObjectId('65d768b1c852a99dc223101e'), ObjectId('65d768b1c852a99dc223101f'), ObjectId('65d768b1c852a99dc2231020'), ObjectId('65d768b1c852a99dc2231021'), ObjectId('65d768b1c852a99dc2231022'), ObjectId('65d768b1c852a99dc2231023'), ObjectId('65d768b1c852a99dc2231024'), ObjectId('65d768b1c852a99dc2231025'), ObjectId('65d768b1c852a99dc2231026'), ObjectId('65d768b1c852a99dc2231027'), ObjectId('65d768b1c852a99dc2231028'), ObjectId('65d768b1c852a99dc2231029'), ObjectId('65d768b1c852a99dc223102a'), ObjectId('65d768b1c852a99dc223102b'), ObjectId('65d768b1c852a99dc223102c'), ObjectId('65d768b1c852a99dc223102d'), ObjectId('65d768b1c852a99dc223102e'), ObjectId('65d768b1c852a99dc223102f'), ObjectId('65d768b1c852a99dc2231030'), ObjectId('65d768b1c852a99dc2231031'), ObjectId('65d768b1c852a99dc2231032'), ObjectId('65d768b1c852a99dc2231033'), ObjectId('65d768b1c852a99dc223
# ...
